# %% [markdown]
# # Лабораторная работа 1: Статистический анализ потребления алкоголя
# # и его влияния на академическую успеваемость студентов
#
# ## I. Введение
#
# ### Цель анализа
# Цель данной работы — комплексно исследовать факторы, связанные с потреблением
# алкоголя среди студентов португальских средних школ, а также проанализировать
# его влияние на академическую успеваемость, здоровье, семейные отношения и
# социальное поведение. В качестве основного источника данных используется
# реальный датасет, собранный в рамках научного исследования P. Cortez и A. Silva.
#
# ### Конкретные статистические задачи
# 1. Описать распределение потребления алкоголя (`Dalc`, `Walc`) в разрезе пола,
#    возраста, типа проживания и романтических отношений.
# 2. Оценить среднюю итоговую оценку (G3) и долю студентов с академическими
#    провалами в группах с разным уровнем алкоголя — через 95% доверительные интервалы.
# 3. Проверить гипотезу о разнице средних оценок (G3) между студентами с низким
#    и высоким потреблением алкоголя в рабочие дни — двухвыборочный t-тест.
# 4. Проверить независимость между высоким потреблением алкоголя в выходные
#    и наличием академических провалов — тест χ².
# 5. Проверить независимость между наличием интернета дома и высоким потреблением
#    алкоголя в выходные — тест χ² или Fisher.
# 6. Сравнить уровень потребления алкоголя (`Dalc`) в группах студентов с разным
#    уровнем образования матери (`Medu`) и отца (`Fedu`) — ANOVA, с целью сравнить
#    силу влияния каждого родителя.
# 7. Проверить различия итоговых оценок (G3) по уровням `Walc` (5 групп) — ANOVA
#    + пост-хок Tukey HSD.
#
# ### Дополнительные исследовательские идеи
# - **Семейные отношения и алкоголь:** влияет ли качество семейных отношений
#   (`famrel`) на уровень `Dalc`/`Walc`? Студенты с плохим `famrel` пьют больше?
# - **Свободное время и выходы:** корреляция между `freetime`, `goout` и `Walc` —
#   визуализация тепловой карты корреляций.
# - **Динамика оценок:** снижаются ли оценки от G1 к G3 у студентов с высоким
#   потреблением алкоголя? Линейный тренд по группам `Walc`.
# - **Здоровье как следствие:** различается ли самооценка здоровья (`health`)
#   у пьющих и непьющих студентов?
# - **Амбиции vs алкоголь:** студенты, желающие поступить в вуз (`higher=yes`),
#   потребляют меньше алкоголя?
# - **Занятость родителей:** влияет ли тип работы матери/отца (`Mjob`, `Fjob`)
#   на уровень алкоголя у студента? (родители дома vs на работе)
# - **Поддержка и контроль:** есть ли разница в потреблении алкоголя между
#   студентами с семейной поддержкой (`famsup`) и без?
#
# ### Описание набора данных
# - **Источник:** UCI Machine Learning Repository / Kaggle
#   *(P. Cortez and A. Silva, FUBUTEC 2008)*
#   https://archive.ics.uci.edu/ml/datasets/STUDENT+ALCOHOL+CONSUMPTION
# - **Количество наблюдений:** 395 студентов
# - **Курс:** Математика (student-mat.csv)
# - **Период сбора данных:** Средние школы Португалии
#
# ### Все переменные датасета
#
# | Переменная | Тип | Описание | Роль в анализе |
# |------------|-----|----------|----------------|
# | `school` | Категориальная | Школа (GP / MS) | Фоновая |
# | `sex` | Категориальная | Пол (M / F) | Описательный анализ, сравнение |
# | `age` | Числовая (15–22) | Возраст | Описательный анализ |
# | `address` | Категориальная | Тип адреса (U / R) | Фоновая |
# | `famsize` | Категориальная | Размер семьи | Фоновая |
# | `Pstatus` | Категориальная | Статус родителей (вместе / раздельно) | Доп. анализ |
# | `Medu` | Числовая (0–4) | Образование матери | ANOVA по Dalc |
# | `Fedu` | Числовая (0–4) | Образование отца | ANOVA по Dalc (сравнение с Medu) |
# | `Mjob` | Категориальная | Работа матери | Доп. анализ |
# | `Fjob` | Категориальная | Работа отца | Доп. анализ |
# | `reason` | Категориальная | Причина выбора школы | Фоновая |
# | `guardian` | Категориальная | Опекун студента | Фоновая |
# | `traveltime` | Числовая (1–4) | Время в дороге | Фоновая |
# | `studytime` | Числовая (1–4) | Время учёбы в неделю | Доп. анализ |
# | `failures` | Числовая (0–4) | Академические провалы | Основная |
# | `schoolsup` | Категориальная | Доп. поддержка школы | Доп. анализ |
# | `famsup` | Категориальная | Поддержка семьи | Доп. анализ |
# | `paid` | Категориальная | Платные доп. занятия | Фоновая |
# | `activities` | Категориальная | Внеклассные активности | Фоновая |
# | `nursery` | Категориальная | Посещал детский сад | Фоновая |
# | `higher` | Категориальная | Хочет высшее образование | Доп. анализ |
# | `internet` | Категориальная | Интернет дома | χ² с Walc |
# | `romantic` | Категориальная | Романтические отношения | Описательный анализ |
# | `famrel` | Числовая (1–5) | Качество семейных отношений | Доп. анализ |
# | `freetime` | Числовая (1–5) | Свободное время после школы | Корреляция с Walc |
# | `goout` | Числовая (1–5) | Выходы с друзьями | Корреляция с Walc |
# | `Dalc` | Числовая (1–5) | Алкоголь в рабочие дни | **Основная** |
# | `Walc` | Числовая (1–5) | Алкоголь в выходные | **Основная** |
# | `health` | Числовая (1–5) | Состояние здоровья | Доп. анализ |
# | `absences` | Числовая (0–93) | Количество пропусков | Основная |
# | `G1` | Числовая (0–20) | Оценка за 1-й триместр | Динамика оценок |
# | `G2` | Числовая (0–20) | Оценка за 2-й триместр | Динамика оценок |
# | `G3` | Числовая (0–20) | Итоговая оценка | **Основная** |

# %%
# =============================================================
# II. Описательный анализ и визуализация данных
# =============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
from scipy import stats
from IPython.display import display

# Настройка стиля графиков (для всех следующих глав)
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams["figure.dpi"] = 130
plt.rcParams["font.size"] = 11

# Общие стили заголовков таблиц
TABLE_HEADER_STYLE = [
    {"selector": "caption",
     "props": [("font-size", "14px"), ("font-weight", "bold"),
               ("color", "#2c3e50"), ("padding-bottom", "10px"),
               ("text-align", "left")]},
    {"selector": "th",
     "props": [("background-color", "#2c3e50"), ("color", "white"),
               ("font-size", "12px"), ("padding", "8px 12px"),
               ("text-align", "center")]},
    {"selector": "td",
     "props": [("padding", "7px 12px"), ("font-size", "11px"),
               ("text-align", "center")]},
    {"selector": "tr:nth-child(even)",
     "props": [("background-color", "#f2f2f2")]},
]

df = pd.read_csv("student-mat.csv", sep=",")
print(f"Датасет загружен: {df.shape[0]} наблюдений, {df.shape[1]} переменных")
# Out:
# Датасет загружен: 395 наблюдений, 33 переменных

# %%
# -------------------------------------------------------------
# 2.1 Статистики для числовых переменных
# -------------------------------------------------------------

numeric_cols = ["age", "Medu", "Fedu", "studytime", "failures",
                "famrel", "freetime", "goout", "Dalc", "Walc",
                "health", "absences", "G1", "G2", "G3"]

desc = df[numeric_cols].agg(["mean", "median", "std", "min", "max"]).T
desc.columns = ["Среднее", "Медиана", "Ст. откл.", "Мин", "Макс"]
desc = desc.round(2)

styled_desc = desc.style \
    .background_gradient(cmap="YlOrRd", subset=["Среднее", "Ст. откл."], axis=0) \
    .highlight_max(subset=["Макс"], color="#2ecc71") \
    .highlight_min(subset=["Мин"], color="#e8f8f5") \
    .format("{:.2f}") \
    .set_caption("Таблица 1 — Описательные статистики числовых переменных") \
    .set_table_styles(TABLE_HEADER_STYLE)

display(styled_desc)
# Out:
# <style type="text/css">
# #T_41b06 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_41b06 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_41b06 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_41b06 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_41b06_row0_col0, #T_41b06_row11_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_41b06_row0_col2, #T_41b06_row9_col2 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_41b06_row1_col0 {
#   background-color: #ffea99;
#   color: #000000;
# }
# #T_41b06_row1_col2, #T_41b06_row2_col2 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_41b06_row1_col3, #T_41b06_row2_col3, #T_41b06_row4_col3, #T_41b06_row11_col3, #T_41b06_row13_col3, #T_41b06_row14_col3 {
#   background-color: #e8f8f5;
# }
# #T_41b06_row2_col0 {
#   background-color: #ffec9d;
#   color: #000000;
# }
# #T_41b06_row3_col0 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_41b06_row3_col2 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_41b06_row4_col0, #T_41b06_row4_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_41b06_row5_col0 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_41b06_row5_col2, #T_41b06_row8_col2 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_41b06_row6_col0 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_41b06_row6_col2 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_41b06_row7_col0 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_41b06_row7_col2 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_41b06_row8_col0 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_41b06_row9_col0 {
#   background-color: #ffeea3;
#   color: #000000;
# }
# #T_41b06_row10_col0 {
#   background-color: #fee288;
#   color: #000000;
# }
# #T_41b06_row10_col2 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_41b06_row11_col0 {
#   background-color: #fec05b;
#   color: #000000;
# }
# #T_41b06_row11_col4 {
#   background-color: #2ecc71;
# }
# #T_41b06_row12_col0 {
#   background-color: #f84528;
#   color: #f1f1f1;
# }
# #T_41b06_row12_col2 {
#   background-color: #feb953;
#   color: #000000;
# }
# #T_41b06_row13_col0 {
#   background-color: #fa4a29;
#   color: #f1f1f1;
# }
# #T_41b06_row13_col2 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_41b06_row14_col0 {
#   background-color: #fc532b;
#   color: #f1f1f1;
# }
# #T_41b06_row14_col2 {
#   background-color: #fd7e38;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_41b06">
#   <caption>Таблица 1 — Описательные статистики числовых переменных</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41b06_level0_col0" class="col_heading level0 col0" >Среднее</th>
#       <th id="T_41b06_level0_col1" class="col_heading level0 col1" >Медиана</th>
#       <th id="T_41b06_level0_col2" class="col_heading level0 col2" >Ст. откл.</th>
#       <th id="T_41b06_level0_col3" class="col_heading level0 col3" >Мин</th>
#       <th id="T_41b06_level0_col4" class="col_heading level0 col4" >Макс</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41b06_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_41b06_row0_col0" class="data row0 col0" >16.70</td>
#       <td id="T_41b06_row0_col1" class="data row0 col1" >17.00</td>
#       <td id="T_41b06_row0_col2" class="data row0 col2" >1.28</td>
#       <td id="T_41b06_row0_col3" class="data row0 col3" >15.00</td>
#       <td id="T_41b06_row0_col4" class="data row0 col4" >22.00</td>
#     </tr>
#     <tr>
#       <th id="T_41b06_level0_row1" class="row_heading level0 row1" >Medu</th>
#       <td id="T_41b06_row1_col0" class="data row1 col0" >2.75</td>
#       <td id="T_41b06_row1_col1" class="data row1 col1" >3.00</td>
#       <td id="T_41b06_row1_col2" class="data row1 col2" >1.09</td>
#       <td id="T_41b06_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_41b06_row1_col4" class="data row1 col4" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_41b06_level0_row2" class="row_heading level0 row2" >Fedu</th>
#       <td id="T_41b06_row2_col0" class="data row2 col0" >2.52</td>
#       <td id="T_41b06_row2_col1" class="data row2 col1" >2.00</td>
#       <td id="T_41b06_row2_col2" class="data row2 col2" >1.09</td>
#       <td id="T_41b06_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_41b06_row2_col4" class="data row2 col4" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_41b06_level0_row3" class="row_heading level0 row3" >studytime</th>
#       <td id="T_41b06_row3_col0" class="data row3 col0" >2.04</td>
#       <td id="T_41b06_row3_col1" class="data row3 col1" >2.00</td>
#       <td id="T_41b06_row3_col2" class="data row3 col2" >0.84</td>
#       <td id="T_41b06_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_41b06_row3_col4" class="data row3 col4" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_41b06_level0_row4" class="row_heading level0 row4" >failures</th>
#       <td id="T_41b06_row4_col0" class="data row4 col0" >0.33</td>
#       <td id="T_41b06_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_41b06_row4_col2" class="data row4 col2" >0.74</td>
#       <td id="T_41b06_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_41b06_row4_col4" class="data row4 col4" >3.00</td>
#     </tr>
#     <tr>
#       <th id="T_41b06_level0_row5" class="row_heading level0 row5" >famrel</th>
#       <td id="T_41b06_row5_col0" class="data row5 col0" >3.94</td>
#       <td id="T_41b06_row5_col1" class="data row5 col1" >4.00</td>
#       <td id="T_41b06_row5_col2" class="data row5 col2" >0.90</td>
#       <td id="T_41b06_row5_col3" class="data row5 col3" >1.00</td>
#       <td id="T_41b06_row5_col4" class="data row5 col4" >5.00</td>
#     </tr>
#     <tr>
#       <th id="T_41b06_level0_row6" class="row_heading level0 row6" >freetime</th>
#       <td id="T_41b06_row6_col0" class="data row6 col0" >3.24</td>
#       <td id="T_41b06_row6_col1" class="data row6 col1" >3.00</td>
#       <td id="T_41b06_row6_col2" class="data row6 col2" >1.00</td>
#       <td id="T_41b06_row6_col3" class="data row6 col3" >1.00</td>
#       <td id="T_41b06_row6_col4" class="data row6 col4" >5.00</td>
#     </tr>
#     <tr>
#       <th id="T_41b06_level0_row7" class="row_heading level0 row7" >goout</th>
#       <td id="T_41b06_row7_col0" class="data row7 col0" >3.11</td>
#       <td id="T_41b06_row7_col1" class="data row7 col1" >3.00</td>
#       <td id="T_41b06_row7_col2" class="data row7 col2" >1.11</td>
#       <td id="T_41b06_row7_col3" class="data row7 col3" >1.00</td>
#       <td id="T_41b06_row7_col4" class="data row7 col4" >5.00</td>
#     </tr>
#     <tr>
#       <th id="T_41b06_level0_row8" class="row_heading level0 row8" >Dalc</th>
#       <td id="T_41b06_row8_col0" class="data row8 col0" >1.48</td>
#       <td id="T_41b06_row8_col1" class="data row8 col1" >1.00</td>
#       <td id="T_41b06_row8_col2" class="data row8 col2" >0.89</td>
#       <td id="T_41b06_row8_col3" class="data row8 col3" >1.00</td>
#       <td id="T_41b06_row8_col4" class="data row8 col4" >5.00</td>
#     </tr>
#     <tr>
#       <th id="T_41b06_level0_row9" class="row_heading level0 row9" >Walc</th>
#       <td id="T_41b06_row9_col0" class="data row9 col0" >2.29</td>
#       <td id="T_41b06_row9_col1" class="data row9 col1" >2.00</td>
#       <td id="T_41b06_row9_col2" class="data row9 col2" >1.29</td>
#       <td id="T_41b06_row9_col3" class="data row9 col3" >1.00</td>
#       <td id="T_41b06_row9_col4" class="data row9 col4" >5.00</td>
#     </tr>
#     <tr>
#       <th id="T_41b06_level0_row10" class="row_heading level0 row10" >health</th>
#       <td id="T_41b06_row10_col0" class="data row10 col0" >3.55</td>
#       <td id="T_41b06_row10_col1" class="data row10 col1" >4.00</td>
#       <td id="T_41b06_row10_col2" class="data row10 col2" >1.39</td>
#       <td id="T_41b06_row10_col3" class="data row10 col3" >1.00</td>
#       <td id="T_41b06_row10_col4" class="data row10 col4" >5.00</td>
#     </tr>
#     <tr>
#       <th id="T_41b06_level0_row11" class="row_heading level0 row11" >absences</th>
#       <td id="T_41b06_row11_col0" class="dat

# %% [markdown]
# Средний возраст студентов составляет 16.7 лет (мин. 15, макс. 22).
# Образование матери (Medu ср. 2.75) незначительно выше образования отца (Fedu ср. 2.52) —
# оба в среднем соответствуют 5–9 классам или среднему образованию.
# Большинство студентов учатся 2–5 часов в неделю (studytime ср. 2.04).
# Среднее число академических провалов — 0.33, медиана 0 — то есть большинство студентов
# не имеют провалов вообще.
# Качество семейных отношений в среднем высокое (famrel ср. 3.94 из 5).
# Потребление алкоголя в будни (Dalc ср. 1.48) заметно ниже чем в выходные (Walc ср. 2.29),
# что соответствует типичной модели поведения молодёжи.
# Среднее количество пропусков — 5.71, однако стандартное отклонение 8.0 и максимум 75
# указывают на наличие студентов с аномально высокой пропускаемостью.
# Средняя итоговая оценка G3 — 10.42 из 20, с высоким разбросом (ст. откл. 4.58).

# %%
# -------------------------------------------------------------
# 2.2 Частоты и пропорции категориальных переменных
# -------------------------------------------------------------

from IPython.display import display, Markdown

cat_info = {
    "sex":       ("Пол",                        
                  "52.7% студентов — девушки (208), 47.3% — юноши (187). "
                  "Выборка практически сбалансирована по полу."),
    "address":   ("Тип адреса",                 
                  "77.7% студентов проживают в городе (U), лишь 22.3% — в сельской местности (R). "
                  "Преобладание городских студентов может влиять на доступность алкоголя."),
    "famsize":   ("Размер семьи",               
                  "71.1% студентов живут в семьях более 3 человек (GT3). "
                  "Большая семья потенциально означает больший контроль со стороны родителей."),
    "Pstatus":   ("Статус родителей",           
                  "89.6% студентов живут с обоими родителями (T — together). "
                  "Только 10.4% имеют раздельно живущих родителей — это меньшинство, "
                  "но важная группа для анализа влияния на алкоголь."),
    "schoolsup": ("Доп. поддержка школы",       
                  "87.1% студентов не получают дополнительной поддержки от школы. "
                  "Лишь 12.9% (51 студент) имеют такую поддержку — вероятно, это "
                  "слабоуспевающие студенты."),
    "famsup":    ("Поддержка семьи",            
                  "61.3% студентов получают поддержку от семьи в учёбе. "
                  "Это большинство, что говорит о вовлечённости родителей."),
    "internet":  ("Интернет дома",              
                  "83.3% студентов имеют доступ к интернету дома. "
                  "16.7% без интернета — интересная группа для сравнения с уровнем алкоголя."),
    "romantic":  ("Романтические отношения",    
                  "66.6% студентов не состоят в романтических отношениях. "
                  "33.4% (132 студента) — состоят. Далее проверим, влияет ли это на Walc."),
    "higher":    ("Желание высшего образования",
                  "94.9% студентов хотят получить высшее образование — подавляющее большинство. "
                  "Только 20 студентов (5.1%) не планируют — но именно эта группа "
                  "представляет особый интерес для анализа алкоголя."),
    "Mjob":      ("Работа матери",              
                  "Наиболее распространённая работа матери — 'other' (35.7%), затем services (26.1%). "
                  "14.9% матерей работают дома (at_home) — это группа с потенциально "
                  "большим контролем над ребёнком."),
    "Fjob":      ("Работа отца",                
                  "54.9% отцов работают в категории 'other', 28.1% — в services. "
                  "Только 5.1% отцов работают дома (at_home) — значительно меньше, чем матерей."),
}

for col, (label, interpretation) in cat_info.items():
    counts = df[col].value_counts()
    props  = df[col].value_counts(normalize=True).mul(100).round(1)
    summary = pd.DataFrame({"Количество": counts, "Доля (%)": props})

    styled = summary.style \
        .bar(subset=["Количество"], color="#3498db", vmin=0) \
        .bar(subset=["Доля (%)"],   color="#2ecc71", vmin=0) \
        .format({"Количество": "{:.0f}", "Доля (%)": "{:.1f}%"}) \
        .set_caption(f"Таблица — {label} ({col})") \
        .set_table_styles(TABLE_HEADER_STYLE)

    display(styled)
    display(Markdown(f"**Интерпретация:** {interpretation}"))
    display(Markdown("---"))
# Out:
# <style type="text/css">
# #T_41d86 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_41d86 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_41d86 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_41d86 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_41d86_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 100.0%, transparent 100.0%);
# }
# #T_41d86_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 100.0%, transparent 100.0%);
# }
# #T_41d86_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 89.9%, transparent 89.9%);
# }
# #T_41d86_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 89.8%, transparent 89.8%);
# }
# </style>
# <table id="T_41d86">
#   <caption>Таблица — Пол (sex)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41d86_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_41d86_level0_col1" class="col_heading level0 col1" >Доля (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41d86_level0_row0" class="row_heading level0 row0" >F</th>
#       <td id="T_41d86_row0_col0" class="data row0 col0" >208</td>
#       <td id="T_41d86_row0_col1" class="data row0 col1" >52.7%</td>
#     </tr>
#     <tr>
#       <th id="T_41d86_level0_row1" class="row_heading level0 row1" >M</th>
#       <td id="T_41d86_row1_col0" class="data row1 col0" >187</td>
#       <td id="T_41d86_row1_col1" class="data row1 col1" >47.3%</td>
#     </tr>
#   </tbody>
# </table>
# **Интерпретация:** 52.7% студентов — девушки (208), 47.3% — юноши (187). Выборка практически сбалансирована по полу.
# ---
# <style type="text/css">
# #T_e2747 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_e2747 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_e2747 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_e2747 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_e2747_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 100.0%, transparent 100.0%);
# }
# #T_e2747_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 100.0%, transparent 100.0%);
# }
# #T_e2747_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 28.7%, transparent 28.7%);
# }
# #T_e2747_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 28.7%, transparent 28.7%);
# }
# </style>
# <table id="T_e2747">
#   <caption>Таблица — Тип адреса (address)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2747_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_e2747_level0_col1" class="col_heading level0 col1" >Доля (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >address</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2747_level0_row0" class="row_heading level0 row0" >U</th>
#       <td id="T_e2747_row0_col0" class="data row0 col0" >307</td>
#       <td id="T_e2747_row0_col1" class="data row0 col1" >77.7%</td>
#     </tr>
#     <tr>
#       <th id="T_e2747_level0_row1" class="row_heading level0 row1" >R</th>
#       <td id="T_e2747_row1_col0" class="data row1 col0" >88</td>
#       <td id="T_e2747_row1_col1" class="data row1 col1" >22.3%</td>
#     </tr>
#   </tbody>
# </table>
# **Интерпретация:** 77.7% студентов проживают в городе (U), лишь 22.3% — в сельской местности (R). Преобладание городских студентов может влиять на доступность алкоголя.
# ---
# <style type="text/css">
# #T_ba6c8 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_ba6c8 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_ba6c8 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_ba6c8 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_ba6c8_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 100.0%, transparent 100.0%);
# }
# #T_ba6c8_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 100.0%, transparent 100.0%);
# }
# #T_ba6c8_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 40.6%, transparent 40.6%);
# }
# #T_ba6c8_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 40.6%, transparent 40.6%);
# }
# </style>
# <table id="T_ba6c8">
#   <caption>Таблица — Размер семьи (famsize)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba6c8_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_ba6c8_level0_col1" class="col_heading level0 col1" >Доля (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >famsize</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba6c8_level0_row0" class="row_heading level0 row0" >GT3</th>
#       <td id="T_ba6c8_row0_col0" class="data row0 col0" >281</td>
#       <td id="T_ba6c8_row0_col1" class="data row0 col1" >71.1%</td>
#     </tr>
#     <tr>
#       <th id="T_ba6c8_level0_row1" class="row_heading level0 row1" >LE3</th>
#       <td id="T_ba6c8_row1_col0" class="data row1 col0" >114</td>
#       <td id="T_ba6c8_row1_col1" class="data row1 col1" >28.9%</td>
#     </tr>
#   </tbody>
# </table>
# **Интерпретация:** 71.1% студентов живут в семьях более 3 человек (GT3). Большая семья потенциально означает больший контроль со стороны родителей.
# ---
# <style type="text/css">
# #T_cba3d caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_cba3d th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_cba3d td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_cba3d tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_cba3d_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 100.0%, transparent 100.0%);
# }
# #T_cba3d_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 100.0%, transparent 100.0%);
# }
# #T_cba3d_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 11.6%, transparent 11.6%);
# }
# #T_cba3d_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 11.6%, transparent 11.6%);
# }
# </style>
# <table id="T_cba3d">
#   <caption>Таблица — Статус родителей (Pstatus)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cba3d_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_cba3d_level0_col1" class="col_heading level0 col1" >Доля (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pstatus</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cba3d_level0_row0" class="row_heading level0 row0" >T</th>
#       <td id="T_cba3d_row0_col0" class="data row0 col0" >354</td>
#       <td id="T_cba3d_row0_col1" class="data row0 col1" >89.6%</td>
#     </tr>
#     <tr>
#       <th id="T_cba3d_level0_row1" class="row_heading level0 row1" >A</th>
#       <td id="T_cba3d_row1_col0" class="data row1 col0" >41</td>
#       <td id="T_cba3d_row1_col1" class="data row1 col1" >10.4%</td>
#     </tr>
#   </tbody>
# </table>
# **Интерпретация:** 89.6% студентов живут с обоими родителями (T — together). Только 10.4% имеют раздельно живущих родителей — это меньшинство, но важная группа для анализа влияния на алкоголь.
# ---
# <style type="text/css">
# #T_c8ef7 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_c8ef7 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_c8ef7 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_c8ef7 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_c8ef7_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 100.0%, transparent 100.0%);
# }
# #T_c8ef7_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 100.0%, transparent 100.0%);
# }
# #T_c8ef7_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 14.8%, transparent 14.8%);
# }
# #T_c8ef7_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 14.8%, transparent 14.8%);
# }
# </style>
# <table id="T_c8ef7">
#   <caption>Таблица — Доп. поддержка школы (schoolsup)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8ef7_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_c8ef7_level0_col1" class="col_heading level0 col1" >Доля (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >schoolsup</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8ef7_level0_row0" class="row_heading level0 row0" >no</th>
#       <td id="T_c8ef7_row0_col0" class="data row0 col0" >344</td>
#       <td id="T_c8ef7_row0_col1" class="data row0 col1" >87.1%</td>
#     </tr>
#     <tr>
#       <th id="T_c8ef7_level0_row1" class="row_heading level0 row1" >yes</th>
#       <td id="T_c8ef7_row1_col0" class="data row1 col0" >51</td>
#       <td id="T_c8ef7_row1_col1" class="data row1 col1" >12.9%</td>
#     </tr>
#   </tbody>
# </table>
# **Интерпретация:** 87.1% студентов не получают дополнительной поддержки от школы. Лишь 12.9% (51 студент) имеют такую поддержку — вероятно, это слабоуспевающие студенты.
# ---
# <style type="text/css">
# #T_75821 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_75821 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_75821 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_75821 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_75821_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 100.0%, transparent 100.0%);
# }
# #T_75821_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 100.0%, transparent 100.0%);
# }
# #T_75821_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 63.2%, transparent 63.2%);
# }
# #T_75821_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 63.1%, transparent 63.1%);
# }
# </style>
# <table id="T_75821">
#   <caption>Таблица — Поддержка семьи (famsup)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75821_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_75821_level0_col1" class="col_heading level0 col1" >Доля (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >famsup</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75821_level0_row0" class="row_heading level0 row0" >yes</th>
#       <td id="T_75821_row0_col0" class="data row0 col0" >242</td>
#       <td id="T_75821_row0_col1" class="data row0 col1" >61.3%</td>
#     </tr>
#     <tr>
#       <th id="T_75821_level0_row1" class="row_heading level0 row1" >no</th>
#       <td id="T_75821_row1_col0" class="data row1 col0" >153</td>
#       <td id="T_75821_row1_col1" class="data row1 col1" >38.7%</td>
#     </tr>
#   </tbody>
# </table>
# **Интерпретация:** 61.3% студентов получают поддержку от семьи в учёбе. Это большинство, что говорит о вовлечённости родителей.
# ---
# <style type="text/css">
# #T_3341a caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_3341a th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_3341a td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_3341a tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_3341a_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 100.0%, transparent 100.0%);
# }
# #T_3341a_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 100.0%, transparent 100.0%);
# }
# #T_3341a_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 20.1%, transparent 20.1%);
# }
# #T_3341a_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 20.0%, transparent 20.0%);
# }
# </style>
# <table id="T_3341a">
#   <caption>Таблица — Интернет дома (internet)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3341a_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_3341a_level0_col1" class="col_heading level0 col1" >Доля (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >internet</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3341a_level0_row0" class="row_heading level0 row0" >yes</th>
#       <td id="T_3341a_row0_col0" class="data row0 col0" >329</td>
#       <td id="T_3341a_row0_col1" class="data row0 col1" >83.3%</td>
#     </tr>
#     <tr>
#       <th id="T_3341a_level0_row1" class="row_heading level0 row1" >no</th>
#       <td id="T_3341a_row1_col0" class="data row1 col0" >66</td>
#       <td id="T_3341a_row1_col1" class="data row1 col1" >16.7%</td>
#     </tr>
#   </tbody>
# </table>
# **Интерпретация:** 83.3% студентов имеют доступ к интернету дома. 16.7% без интернета — интересная группа для сравнения с уровнем алкоголя.
# ---
# <style type="text/css">
# #T_29823 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_29823 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_29823 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_29823 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_29823_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 100.0%, transparent 100.0%);
# }
# #T_29823_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 100.0%, transparent 100.0%);
# }
# #T_29823_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 50.2%, transparent 50.2%);
# }
# #T_29823_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 50.2%, transparent 50.2%);
# }
# </style>
# <table id="T_29823">
#   <caption>Таблица — Романтические отношения (romantic)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29823_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_29823_level0_col1" class="col_heading level0 col1" >Доля (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >romantic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29823_level0_row0" class="row_heading level0 row0" >no</th>
#       <td id="T_29823_row0_col0" class="data row0 col0" >263</td>
#       <td id="T_29823_row0_col1" class="data row0 col1" >66.6%</td>
#     </tr>
#     <tr>
#       <th id="T_29823_level0_row1" class="row_heading level0 row1" >yes</th>
#       <td id="T_29823_row1_col0" class="data row1 col0" >132</td>
#       <td id="T_29823_row1_col1" class="data row1 col1" >33.4%</td>
#     </tr>
#   </tbody>
# </table>
# **Интерпретация:** 66.6% студентов не состоят в романтических отношениях. 33.4% (132 студента) — состоят. Далее проверим, влияет ли это на Walc.
# ---
# <style type="text/css">
# #T_8d006 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_8d006 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_8d006 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_8d006 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_8d006_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 100.0%, transparent 100.0%);
# }
# #T_8d006_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 100.0%, transparent 100.0%);
# }
# #T_8d006_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 5.3%, transparent 5.3%);
# }
# #T_8d006_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 5.4%, transparent 5.4%);
# }
# </style>
# <table id="T_8d006">
#   <caption>Таблица — Желание высшего образования (higher)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d006_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_8d006_level0_col1" class="col_heading level0 col1" >Доля (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >higher</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d006_level0_row0" class="row_heading level0 row0" >yes</th>
#       <td id="T_8d006_row0_col0" class="data row0 col0" >375</td>
#       <td id="T_8d006_row0_col1" class="data row0 col1" >94.9%</td>
#     </tr>
#     <tr>
#       <th id="T_8d006_level0_row1" class="row_heading level0 row1" >no</th>
#       <td id="T_8d006_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_8d006_row1_col1" class="data row1 col1" >5.1%</td>
#     </tr>
#   </tbody>
# </table>
# **Интерпретация:** 94.9% студентов хотят получить высшее образование — подавляющее большинство. Только 20 студентов (5.1%) не планируют — но именно эта группа представляет особый интерес для анализа алкоголя.
# ---
# <style type="text/css">
# #T_6f7cf caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_6f7cf th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_6f7cf td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_6f7cf tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_6f7cf_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 100.0%, transparent 100.0%);
# }
# #T_6f7cf_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 100.0%, transparent 100.0%);
# }
# #T_6f7cf_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 73.0%, transparent 73.0%);
# }
# #T_6f7cf_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 73.1%, transparent 73.1%);
# }
# #T_6f7cf_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 41.8%, transparent 41.8%);
# }
# #T_6f7cf_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 41.7%, transparent 41.7%);
# }
# #T_6f7cf_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 41.1%, transparent 41.1%);
# }
# #T_6f7cf_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 41.2%, transparent 41.2%);
# }
# #T_6f7cf_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 24.1%, transparent 24.1%);
# }
# #T_6f7cf_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 24.1%, transparent 24.1%);
# }
# </style>
# <table id="T_6f7cf">
#   <caption>Таблица — Работа матери (Mjob)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f7cf_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_6f7cf_level0_col1" class="col_heading level0 col1" >Доля (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Mjob</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f7cf_level0_row0" class="row_heading level0 row0" >other</th>
#       <td id="T_6f7cf_row0_col0" class="data row0 col0" >141</td>
#       <td id="T_6f7cf_row0_col1" class="data row0 col1" >35.7%</td>
#     </tr>
#     <tr>
#       <th id="T_6f7cf_level0_row1" class="row_heading level0 row1" >services</th>
#       <td id="T_6f7cf_row1_col0" class="data row1 col0" >103</td>
#       <td id="T_6f7cf_row1_col1" class="data row1 col1" >26.1%</td>
#     </tr>
#     <tr>
#       <th id="T_6f7cf_level0_row2" class="row_heading level0 row2" >at_home</th>
#       <td id="T_6f7cf_row2_col0" class="data row2 col0" >59</td>
#       <td id="T_6f7cf_row2_col1" class="data row2 col1" >14.9%</td>
#     </tr>
#     <tr>
#       <th id="T_6f7cf_level0_row3" class="row_heading level0 row3" >teacher</th>
#       <td id="T_6f7cf_row3_col0" class="data row3 col0" >58</td>
#       <td id="T_6f7cf_row3_col1" class="data row3 col1" >14.7%</td>
#     </tr>
#     <tr>
#       <th id="T_6f7cf_level0_row4" class="row_heading level0 row4" >health</th>
#       <td id="T_6f7cf_row4_col0" class="data row4 col0" >34</td>
#       <td id="T_6f7cf_row4_col1" class="data row4 col1" >8.6%</td>
#     </tr>
#   </tbody>
# </table>
# **Интерпретация:** Наиболее распространённая работа матери — 'other' (35.7%), затем services (26.1%). 14.9% матерей работают дома (at_home) — это группа с потенциально большим контролем над ребёнком.
# ---
# <style type="text/css">
# #T_14e61 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_14e61 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_14e61 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_14e61 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_14e61_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 100.0%, transparent 100.0%);
# }
# #T_14e61_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 100.0%, transparent 100.0%);
# }
# #T_14e61_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 51.2%, transparent 51.2%);
# }
# #T_14e61_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 51.2%, transparent 51.2%);
# }
# #T_14e61_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 13.4%, transparent 13.4%);
# }
# #T_14e61_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 13.3%, transparent 13.3%);
# }
# #T_14e61_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 9.2%, transparent 9.2%);
# }
# #T_14e61_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 9.3%, transparent 9.3%);
# }
# #T_14e61_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 8.3%, transparent 8.3%);
# }
# #T_14e61_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 8.4%, transparent 8.4%);
# }
# </style>
# <table id="T_14e61">
#   <caption>Таблица — Работа отца (Fjob)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14e61_level0_col0" class="col_heading level0 col0" >Количество</th>
#       <th id="T_14e61_level0_col1" class="col_heading level0 col1" >Доля (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fjob</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14e61_level0_row0" class="row_heading level0 row0" >other</th>
#       <td id="T_14e61_row0_col0" class="data row0 col0" >217</td>
#       <td id="T_14e61_row0_col1" class="data row0 col1" >54.9%</td>
#     </tr>
#     <tr>
#       <th id="T_14e61_level0_row1" class="row_heading level0 row1" >services</th>
#       <td id="T_14e61_row1_col0" class="data row1 col0" >111</td>
#       <td id="T_14e61_row1_col1" class="data row1 col1" >28.1%</td>
#     </tr>
#     <tr>
#       <th id="T_14e61_level0_row2" class="row_heading level0 row2" >teacher</th>
#       <td id="T_14e61_row2_col0" class="data row2 col0" >29</td>
#       <td id="T_14e61_row2_col1" class="data row2 col1" >7.3%</td>
#     </tr>
#     <tr>
#       <th id="T_14e61_level0_row3" class="row_heading level0 row3" >at_home</th>
#       <td id="T_14e61_row3_col0" class="data row3 col0" >20</td>
#       <td id="T_14e61_row3_col1" class="data row3 col1" >5.1%</td>
#     </tr>
#     <tr>
#       <th id="T_14e61_level0_row4" class="row_heading level0 row4" >health</th>
#       <td id="T_14e61_row4_col0" class="data row4 col0" >18</td>
#       <td id="T_14e61_row4_col1" class="data row4 col1" >4.6%</td>
#     </tr>
#   </tbody>
# </table>
# **Интерпретация:** 54.9% отцов работают в категории 'other', 28.1% — в services. Только 5.1% отцов работают дома (at_home) — значительно меньше, чем матерей.
# ---

# %%
# -------------------------------------------------------------
# 2.3 Гистограммы Dalc и Walc раздельно по полу
# -------------------------------------------------------------

colors = {"M": "#4C72B0", "F": "#DD8452"}

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, col, title in zip(axes,
                          ["Dalc", "Walc"],
                          ["Потребление алкоголя в рабочие дни (Dalc)",
                           "Потребление алкоголя в выходные (Walc)"]):
    for sex, grp in df.groupby("sex"):
        ax.hist(grp[col], bins=np.arange(0.5, 6.5, 1),
                alpha=0.6, label=f"Пол: {sex}",
                color=colors[sex], edgecolor="white", linewidth=0.8)
    ax.set_title(title, fontsize=12, fontweight="bold")
    ax.set_xlabel("Уровень (1 = очень низкий, 5 = очень высокий)")
    ax.set_ylabel("Количество студентов")
    ax.legend()
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))

plt.suptitle("Распределение потребления алкоголя по полу",
             fontsize=14, fontweight="bold", y=1.02)
plt.tight_layout()
plt.savefig("hist_alcohol_sex.png", bbox_inches="tight")
plt.show()

"""
Интерпретация:
Большинство студентов имеют низкий уровень потребления алкоголя (1–2).
Мужчины в обеих категориях демонстрируют более высокое потребление,
особенно заметно в выходные дни (Walc).
"""
# Out:
# '\nИнтерпретация:\nБольшинство студентов имеют низкий уровень потребления алкоголя (1–2).\nМужчины в обеих категориях демонстрируют более высокое потребление,\nособенно заметно в выходные дни (Walc).\n'

# %%
# -------------------------------------------------------------
# 2.4 Boxplot: G3 по уровням Walc
# -------------------------------------------------------------

palette_walc = ["#2ecc71", "#3498db", "#f39c12", "#e67e22", "#e74c3c"]

fig, ax = plt.subplots(figsize=(10, 6))
sns.boxplot(data=df, x="Walc", y="G3",
            palette=palette_walc, width=0.5,
            linewidth=1.5,
            flierprops=dict(marker="o", alpha=0.5), ax=ax)
ax.set_title("Итоговая оценка (G3) по уровням потребления алкоголя в выходные",
             fontsize=13, fontweight="bold")
ax.set_xlabel("Walc (1 = очень низкий, 5 = очень высокий)")
ax.set_ylabel("Итоговая оценка G3 (0–20)")

plt.tight_layout()
plt.savefig("boxplot_G3_Walc.png", bbox_inches="tight")
plt.show()
# Out:
# /tmp/ipykernel_31401/2258712429.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Walc", y="G3",

# %% [markdown]
# **Что такое boxplot (ящик с усами)?**
# Каждый "ящик" показывает:
# - **Линия внутри** — медиана (50% данных ниже, 50% выше)
# - **Границы ящика** — 25-й и 75-й перцентили (интерквартильный размах, IQR)
# - **Усы** — данные в пределах 1.5×IQR от границ ящика
# - **Точки за усами** — выбросы (аномальные значения)
#
# Каждый цвет соответствует одному уровню Walc (1–5).
#
# Медиана G3 снижается с ростом Walc: у студентов с Walc=1 медиана ≈ 11–12,
# тогда как при Walc=5 она опускается до ≈ 8–9.
# Интерквартильный размах (ширина ящика) увеличивается при высоком Walc,
# что указывает на большую вариабельность оценок среди активно пьющих студентов.
# Высокое число выбросов вниз при Walc=4–5 свидетельствует о риске
# академического провала при высоком потреблении алкоголя.

# %%
# -------------------------------------------------------------
# 2.5 Heatmap корреляций
# -------------------------------------------------------------

corr_cols = ["Dalc", "Walc", "G1", "G2", "G3",
             "absences", "failures", "goout",
             "freetime", "famrel", "health",
             "studytime", "Medu", "Fedu"]

corr_matrix = df[corr_cols].corr()

fig, ax = plt.subplots(figsize=(12, 10))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, mask=mask, annot=True, fmt=".2f",
            cmap="coolwarm", center=0, linewidths=0.5,
            linecolor="white", square=True,
            cbar_kws={"shrink": 0.8}, ax=ax)
ax.set_title("Тепловая карта корреляций числовых переменных",
             fontsize=14, fontweight="bold", pad=15)

plt.tight_layout()
plt.savefig("heatmap_correlations.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# **Что такое корреляция?**
# Корреляция Пирсона измеряет линейную связь между двумя числовыми переменными.
# Значение от -1 до +1:
# - **+1** — идеальная положительная связь (оба растут вместе)
# - **0** — нет линейной связи
# - **-1** — идеальная отрицательная связь (один растёт — другой падает)
#
# **Как читать карту:**
# - 🔴 Красный цвет — сильная положительная корреляция
# - 🔵 Синий цвет — сильная отрицательная корреляция
# - ⚪ Белый/бледный — слабая или отсутствующая связь
# - Показана только нижняя половина (верхняя — зеркальное отражение)
#
# **Интерпретация:**
# Dalc и Walc коррелируют между собой (r ≈ 0.65) — студенты, пьющие в будни,
# пьют и в выходные. Оба показателя отрицательно связаны с G3 (r ≈ -0.20 до -0.28)
# и studytime, и положительно — с goout (r ≈ 0.42) и failures.
# Medu и Fedu положительно коррелируют с G3 (r ≈ 0.21–0.25),
# подтверждая что образование родителей влияет на успеваемость детей.
# G1, G2, G3 имеют очень высокую взаимную корреляцию (r > 0.85) —
# оценки стабильны на протяжении года.

# %%
# -------------------------------------------------------------
# 2.6 Линейный тренд G1 → G2 → G3 по группам Walc
# -------------------------------------------------------------

df["Walc_group"] = pd.cut(df["Walc"], bins=[0, 2, 3, 5],
                           labels=["Низкий (1–2)", "Средний (3)", "Высокий (4–5)"])

trend = df.groupby("Walc_group", observed=True)[["G1", "G2", "G3"]].mean()

# Таблица средних оценок по группам
styled_trend = trend.style \
    .background_gradient(cmap="RdYlGn", axis=None) \
    .format("{:.2f}") \
    .set_caption("Таблица 2 — Средние оценки по группам потребления алкоголя") \
    .set_table_styles(TABLE_HEADER_STYLE)

display(styled_trend)

# График
colors_trend = ["#2ecc71", "#f39c12", "#e74c3c"]
markers = ["o", "s", "^"]

fig, ax = plt.subplots(figsize=(10, 6))
for (group, row), color, marker in zip(trend.iterrows(), colors_trend, markers):
    ax.plot(["G1", "G2", "G3"], row.values,
            marker=marker, linewidth=2.5, markersize=9,
            label=f"Walc: {group}", color=color)
    for x, y in zip(["G1", "G2", "G3"], row.values):
        ax.annotate(f"{y:.1f}", (x, y),
                    textcoords="offset points", xytext=(0, 10),
                    ha="center", fontsize=9, color=color)

ax.set_title("Динамика оценок G1 → G2 → G3 по группам потребления алкоголя",
             fontsize=13, fontweight="bold")
ax.set_xlabel("Период оценивания")
ax.set_ylabel("Средняя оценка (0–20)")
ax.legend(title="Группа Walc")
ax.set_ylim(8, 14)

plt.tight_layout()
plt.savefig("trend_grades_walc.png", bbox_inches="tight")
plt.show()
# Out:
# <style type="text/css">
# #T_1ad0c caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_1ad0c th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_1ad0c td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_1ad0c tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_1ad0c_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1ad0c_row0_col1 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_1ad0c_row0_col2 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_1ad0c_row1_col0 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_1ad0c_row1_col1 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_1ad0c_row1_col2 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_1ad0c_row2_col0, #T_1ad0c_row2_col1 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_1ad0c_row2_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1ad0c">
#   <caption>Таблица 2 — Средние оценки по группам потребления алкоголя</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ad0c_level0_col0" class="col_heading level0 col0" >G1</th>
#       <th id="T_1ad0c_level0_col1" class="col_heading level0 col1" >G2</th>
#       <th id="T_1ad0c_level0_col2" class="col_heading level0 col2" >G3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Walc_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ad0c_level0_row0" class="row_heading level0 row0" >Низкий (1–2)</th>
#       <td id="T_1ad0c_row0_col0" class="data row0 col0" >11.21</td>
#       <td id="T_1ad0c_row0_col1" class="data row0 col1" >10.89</td>
#       <td id="T_1ad0c_row0_col2" class="data row0 col2" >10.50</td>
#     </tr>
#     <tr>
#       <th id="T_1ad0c_level0_row1" class="row_heading level0 row1" >Средний (3)</th>
#       <td id="T_1ad0c_row1_col0" class="data row1 col0" >10.94</td>
#       <td id="T_1ad0c_row1_col1" class="data row1 col1" >10.91</td>
#       <td id="T_1ad0c_row1_col2" class="data row1 col2" >10.72</td>
#     </tr>
#     <tr>
#       <th id="T_1ad0c_level0_row2" class="row_heading level0 row2" >Высокий (4–5)</th>
#       <td id="T_1ad0c_row2_col0" class="data row2 col0" >9.97</td>
#       <td id="T_1ad0c_row2_col1" class="data row2 col1" >9.97</td>
#       <td id="T_1ad0c_row2_col2" class="data row2 col2" >9.85</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Интерпретация:
# Студенты с низким Walc стабильно получают более высокие оценки.
# У всех групп наблюдается лёгкое снижение от G1 к G3, однако
# у студентов с высоким Walc этот спад выражен сильнее.

# %%
# -------------------------------------------------------------
# 2.7 Grouped bar chart: средний Dalc по Mjob и Fjob
# -------------------------------------------------------------

job_palette = ["#9b59b6", "#3498db", "#2ecc71", "#e67e22", "#e74c3c"]

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

for ax, job_col, title in zip(axes,
                               ["Mjob", "Fjob"],
                               ["Средний Dalc по работе матери",
                                "Средний Dalc по работе отца"]):
    job_means = df.groupby(job_col)["Dalc"].mean().sort_values(ascending=False)
    bars = ax.bar(job_means.index, job_means.values,
                  color=job_palette, edgecolor="white", linewidth=0.8)
    ax.set_title(title, fontsize=12, fontweight="bold")
    ax.set_xlabel("Тип работы")
    ax.set_ylabel("Средний уровень Dalc")
    ax.set_ylim(0, 3)
    for bar, val in zip(bars, job_means.values):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.05,
                f"{val:.2f}", ha="center", va="bottom", fontsize=9)

plt.suptitle("Потребление алкоголя в зависимости от занятости родителей",
             fontsize=14, fontweight="bold", y=1.02)
plt.tight_layout()
plt.savefig("bar_dalc_jobs.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# Интерпретация:
# Студенты, чьи родители работают дома (at_home), имеют более высокий
# Dalc. Дети родителей-преподавателей демонстрируют более низкий уровень
# потребления алкоголя в будни.

# %%
# -------------------------------------------------------------
# 2.8 Scatter plot: goout vs Walc по полу
# -------------------------------------------------------------

fig, ax = plt.subplots(figsize=(10, 6))
for sex, grp in df.groupby("sex"):
    jitter_x = grp["goout"] + np.random.uniform(-0.15, 0.15, size=len(grp))
    jitter_y = grp["Walc"]  + np.random.uniform(-0.15, 0.15, size=len(grp))
    ax.scatter(jitter_x, jitter_y, alpha=0.6, s=60,
               label=f"Пол: {sex}", color=colors[sex],
               edgecolors="white", linewidth=0.5)

ax.set_title("Зависимость между частотой выходов с друзьями и алкоголем в выходные",
             fontsize=13, fontweight="bold")
ax.set_xlabel("goout (1 = очень редко, 5 = очень часто)")
ax.set_ylabel("Walc (1 = очень низкий, 5 = очень высокий)")
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
ax.legend()

plt.tight_layout()
plt.savefig("scatter_goout_walc.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# Интерпретация:
# Явная положительная зависимость между goout и Walc. Мужчины
# сосредоточены в зоне более высоких значений обеих переменных,
# подтверждая гендерные различия в социально-алкогольном поведении.

# %%
# -------------------------------------------------------------
# 2.9 Violin plot: famrel vs Walc
# -------------------------------------------------------------

fig, ax = plt.subplots(figsize=(10, 6))
sns.violinplot(data=df, x="famrel", y="Walc",
               palette="Set2", inner="box",
               linewidth=1.5, ax=ax)
ax.set_title("Качество семейных отношений и потребление алкоголя в выходные",
             fontsize=13, fontweight="bold")
ax.set_xlabel("famrel (1 = очень плохие, 5 = отличные отношения)")
ax.set_ylabel("Walc (1 = очень низкий, 5 = очень высокий)")

plt.tight_layout()
plt.savefig("violin_famrel_walc.png", bbox_inches="tight")
plt.show()
# Out:
# /tmp/ipykernel_31401/930680115.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="famrel", y="Walc",

# %% [markdown]
# **Что такое violin plot?**
# Violin plot — расширенная версия boxplot. Ширина "скрипки" в каждой точке
# показывает плотность данных (как гистограмма, повёрнутая набок).
# Чем шире в какой-то точке — тем больше студентов с таким значением.
# Внутри находится мини-boxplot (медиана + IQR).
#
# **Преимущество перед boxplot:** виден не только разброс,
# но и форма распределения (одновершинное, двувершинное и т.д.)
#
# **Интерпретация:**
# При famrel=1–2 "скрипка" широкая в верхней части — много студентов
# с высоким Walc. При famrel=4–5 масса распределения смещается вниз,
# что подтверждает: хорошие семейные отношения связаны с меньшим
# потреблением алкоголя в выходные.

# %%
# -------------------------------------------------------------
# 2.10 Stacked bar: higher vs Walc_group
# -------------------------------------------------------------

higher_walc = df.groupby(["higher", "Walc_group"],
                          observed=True).size().unstack(fill_value=0)
higher_walc_pct = higher_walc.div(higher_walc.sum(axis=1), axis=0) * 100

# Таблица процентов
styled_higher = higher_walc_pct.style \
    .background_gradient(cmap="RdYlGn_r", axis=1) \
    .format("{:.1f}%") \
    .set_caption("Таблица 3 — Распределение Walc по группам higher (%)") \
    .set_table_styles(TABLE_HEADER_STYLE)

display(styled_higher)

# График
fig, ax = plt.subplots(figsize=(10, 6))
higher_walc_pct.plot(kind="bar", stacked=True,
                     color=["#2ecc71", "#f39c12", "#e74c3c"],
                     edgecolor="white", linewidth=0.8, ax=ax)
ax.set_title("Амбиции студентов (higher) и уровень потребления алкоголя",
             fontsize=13, fontweight="bold")
ax.set_xlabel("Желание получить высшее образование")
ax.set_ylabel("Доля студентов (%)")
ax.set_xticklabels(["Нет", "Да"], rotation=0)
ax.legend(title="Группа Walc", bbox_to_anchor=(1.05, 1))

plt.tight_layout()
plt.savefig("stacked_higher_walc.png", bbox_inches="tight")
plt.show()
# Out:
# <style type="text/css">
# #T_2b9e6 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_2b9e6 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_2b9e6 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_2b9e6 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_2b9e6_row0_col0, #T_2b9e6_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_2b9e6_row0_col1, #T_2b9e6_row1_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2b9e6_row0_col2 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_2b9e6_row1_col1 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2b9e6">
#   <caption>Таблица 3 — Распределение Walc по группам higher (%)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Walc_group</th>
#       <th id="T_2b9e6_level0_col0" class="col_heading level0 col0" >Низкий (1–2)</th>
#       <th id="T_2b9e6_level0_col1" class="col_heading level0 col1" >Средний (3)</th>
#       <th id="T_2b9e6_level0_col2" class="col_heading level0 col2" >Высокий (4–5)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >higher</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b9e6_level0_row0" class="row_heading level0 row0" >no</th>
#       <td id="T_2b9e6_row0_col0" class="data row0 col0" >45.0%</td>
#       <td id="T_2b9e6_row0_col1" class="data row0 col1" >15.0%</td>
#       <td id="T_2b9e6_row0_col2" class="data row0 col2" >40.0%</td>
#     </tr>
#     <tr>
#       <th id="T_2b9e6_level0_row1" class="row_heading level0 row1" >yes</th>
#       <td id="T_2b9e6_row1_col0" class="data row1 col0" >60.5%</td>
#       <td id="T_2b9e6_row1_col1" class="data row1 col1" >20.5%</td>
#       <td id="T_2b9e6_row1_col2" class="data row1 col2" >18.9%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Что показывает stacked bar (составная столбчатая диаграмма)?**
# Каждый столбец = 100% студентов в данной группе (higher=yes или no).
# Цвета показывают долю студентов с низким / средним / высоким Walc
# внутри каждой группы. Это позволяет сравнивать структуру,
# а не абсолютные числа (что важно, т.к. группа higher=no всего 20 человек).
#
# **Интерпретация:**
# Среди 20 студентов без амбиций (higher=no) доля с высоким Walc (4–5)
# значительно выше, чем среди 375 амбициозных студентов.
# Это говорит о том, что академическая мотивация и сдержанное
# потребление алкоголя взаимосвязаны.

# %% [markdown]
# ## III. Оценка параметров и доверительные интервалы
#
# ### Что такое доверительный интервал?
# Доверительный интервал (ДИ) — это диапазон значений, который с заданной
# вероятностью (95%) содержит истинный параметр генеральной совокупности.
#
# **Интерпретация 95% ДИ:**
# Если повторить выборку 100 раз, примерно в 95 случаях построенный интервал
# будет содержать истинное значение параметра.
#
# **Формула для среднего:**
# ДИ = x̄ ± t(α/2, n-1) × (s / √n)
#
# где:
# - x̄ — выборочное среднее
# - s — стандартное отклонение
# - n — размер выборки
# - t — критическое значение t-распределения Стьюдента

# %%
# =============================================================
# III. Оценка параметров и доверительные интервалы
# =============================================================

from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %%
# -------------------------------------------------------------
# 3.1 ДИ для средней итоговой оценки G3
# -------------------------------------------------------------

g3 = df["G3"]
n  = len(g3)
mean_g3 = g3.mean()
std_g3  = g3.std(ddof=1)
se_g3   = std_g3 / np.sqrt(n)

ci_g3 = stats.t.interval(0.95, df=n-1, loc=mean_g3, scale=se_g3)

result_g3 = pd.DataFrame({
    "Параметр": ["Среднее G3", "Медиана G3", "Ст. откл.", "Размер выборки",
                 "Стандартная ошибка", "ДИ нижняя граница", "ДИ верхняя граница"],
    "Значение": [round(mean_g3, 3), round(g3.median(), 3),
                 round(std_g3, 3), n,
                 round(se_g3, 4),
                 round(ci_g3[0], 3), round(ci_g3[1], 3)]
}).set_index("Параметр")

styled_g3 = result_g3.style \
    .highlight_between(subset=pd.IndexSlice[["ДИ нижняя граница",
                                              "ДИ верхняя граница"], :],
                       color="#d5f5e3") \
    .set_caption("Таблица 4 — 95% ДИ для средней итоговой оценки G3") \
    .set_table_styles(TABLE_HEADER_STYLE)

display(styled_g3)
# Out:
# <style type="text/css">
# #T_172ac caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_172ac th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_172ac td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_172ac tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_172ac_row5_col0, #T_172ac_row6_col0 {
#   background-color: #d5f5e3;
# }
# </style>
# <table id="T_172ac">
#   <caption>Таблица 4 — 95% ДИ для средней итоговой оценки G3</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_172ac_level0_col0" class="col_heading level0 col0" >Значение</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Параметр</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_172ac_level0_row0" class="row_heading level0 row0" >Среднее G3</th>
#       <td id="T_172ac_row0_col0" class="data row0 col0" >10.415000</td>
#     </tr>
#     <tr>
#       <th id="T_172ac_level0_row1" class="row_heading level0 row1" >Медиана G3</th>
#       <td id="T_172ac_row1_col0" class="data row1 col0" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_172ac_level0_row2" class="row_heading level0 row2" >Ст. откл.</th>
#       <td id="T_172ac_row2_col0" class="data row2 col0" >4.581000</td>
#     </tr>
#     <tr>
#       <th id="T_172ac_level0_row3" class="row_heading level0 row3" >Размер выборки</th>
#       <td id="T_172ac_row3_col0" class="data row3 col0" >395.000000</td>
#     </tr>
#     <tr>
#       <th id="T_172ac_level0_row4" class="row_heading level0 row4" >Стандартная ошибка</th>
#       <td id="T_172ac_row4_col0" class="data row4 col0" >0.230500</td>
#     </tr>
#     <tr>
#       <th id="T_172ac_level0_row5" class="row_heading level0 row5" >ДИ нижняя граница</th>
#       <td id="T_172ac_row5_col0" class="data row5 col0" >9.962000</td>
#     </tr>
#     <tr>
#       <th id="T_172ac_level0_row6" class="row_heading level0 row6" >ДИ верхняя граница</th>
#       <td id="T_172ac_row6_col0" class="data row6 col0" >10.868000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Интерпретация:**
# Средняя итоговая оценка по математике составляет **10.42** из 20.
# 95% доверительный интервал: **(~9.97 ; ~10.87)**.
# Это означает: с вероятностью 95% истинная средняя оценка всех студентов
# португальских школ находится в этом диапазоне.
# Интервал относительно узкий (ширина ≈ 0.9), что говорит о достаточном
# размере выборки (n=395) для точной оценки.

# %%
# -------------------------------------------------------------
# 3.2 ДИ для средней оценки G3 по группам Dalc (низкий vs высокий)
# -------------------------------------------------------------

low_dalc  = df[df["Dalc"] <= 2]["G3"]
high_dalc = df[df["Dalc"] >= 3]["G3"]

def ci_summary(group, label):
    n    = len(group)
    mean = group.mean()
    std  = group.std(ddof=1)
    se   = std / np.sqrt(n)
    ci   = stats.t.interval(0.95, df=n-1, loc=mean, scale=se)
    return {
        "Группа": label,
        "n": n,
        "Среднее G3": round(mean, 3),
        "Ст. откл.": round(std, 3),
        "Ст. ошибка": round(se, 4),
        "ДИ нижняя": round(ci[0], 3),
        "ДИ верхняя": round(ci[1], 3),
    }

ci_dalc = pd.DataFrame([
    ci_summary(low_dalc,  "Низкий Dalc (1–2)"),
    ci_summary(high_dalc, "Высокий Dalc (3–5)"),
]).set_index("Группа")

styled_dalc = ci_dalc.style \
    .background_gradient(cmap="RdYlGn", subset=["Среднее G3"], axis=0) \
    .highlight_between(subset=["ДИ нижняя", "ДИ верхняя"], color="#d5f5e3") \
    .format({"n": "{:.0f}", "Среднее G3": "{:.3f}",
             "Ст. откл.": "{:.3f}", "Ст. ошибка": "{:.4f}",
             "ДИ нижняя": "{:.3f}", "ДИ верхняя": "{:.3f}"}) \
    .set_caption("Таблица 5 — 95% ДИ для G3 по группам Dalc") \
    .set_table_styles(TABLE_HEADER_STYLE)

display(styled_dalc)
# Out:
# <style type="text/css">
# #T_f23f2 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_f23f2 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_f23f2 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_f23f2 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_f23f2_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f23f2_row0_col4, #T_f23f2_row0_col5, #T_f23f2_row1_col4, #T_f23f2_row1_col5 {
#   background-color: #d5f5e3;
# }
# #T_f23f2_row1_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f23f2">
#   <caption>Таблица 5 — 95% ДИ для G3 по группам Dalc</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f23f2_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_f23f2_level0_col1" class="col_heading level0 col1" >Среднее G3</th>
#       <th id="T_f23f2_level0_col2" class="col_heading level0 col2" >Ст. откл.</th>
#       <th id="T_f23f2_level0_col3" class="col_heading level0 col3" >Ст. ошибка</th>
#       <th id="T_f23f2_level0_col4" class="col_heading level0 col4" >ДИ нижняя</th>
#       <th id="T_f23f2_level0_col5" class="col_heading level0 col5" >ДИ верхняя</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Группа</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f23f2_level0_row0" class="row_heading level0 row0" >Низкий Dalc (1–2)</th>
#       <td id="T_f23f2_row0_col0" class="data row0 col0" >351</td>
#       <td id="T_f23f2_row0_col1" class="data row0 col1" >10.416</td>
#       <td id="T_f23f2_row0_col2" class="data row0 col2" >4.738</td>
#       <td id="T_f23f2_row0_col3" class="data row0 col3" >0.2529</td>
#       <td id="T_f23f2_row0_col4" class="data row0 col4" >9.919</td>
#       <td id="T_f23f2_row0_col5" class="data row0 col5" >10.913</td>
#     </tr>
#     <tr>
#       <th id="T_f23f2_level0_row1" class="row_heading level0 row1" >Высокий Dalc (3–5)</th>
#       <td id="T_f23f2_row1_col0" class="data row1 col0" >44</td>
#       <td id="T_f23f2_row1_col1" class="data row1 col1" >10.409</td>
#       <td id="T_f23f2_row1_col2" class="data row1 col2" >3.098</td>
#       <td id="T_f23f2_row1_col3" class="data row1 col3" >0.4670</td>
#       <td id="T_f23f2_row1_col4" class="data row1 col4" >9.467</td>
#       <td id="T_f23f2_row1_col5" class="data row1 col5" >11.351</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Студенты с низким Dalc (1–2) имеют заметно более высокую среднюю оценку
# по сравнению с группой высокого Dalc (3–5).
# Важно отметить: если доверительные интервалы двух групп **не перекрываются**,
# это является первым признаком статистически значимой разницы —
# которую мы формально проверим в Главе IV t-тестом.

# %%
# -------------------------------------------------------------
# 3.3 Визуализация ДИ для G3 по группам Dalc
# -------------------------------------------------------------

fig, ax = plt.subplots(figsize=(10, 5))

groups   = ci_dalc.index.tolist()
means    = ci_dalc["Среднее G3"].values
ci_lower = ci_dalc["ДИ нижняя"].values
ci_upper = ci_dalc["ДИ верхняя"].values
errors   = [means - ci_lower, ci_upper - means]
colors_ci = ["#2ecc71", "#e74c3c"]

bars = ax.bar(groups, means, color=colors_ci,
              edgecolor="white", linewidth=0.8,
              alpha=0.85, width=0.4)

ax.errorbar(groups, means, yerr=errors,
            fmt="none", color="#2c3e50",
            capsize=10, capthick=2, linewidth=2)

for bar, mean, lo, hi in zip(bars, means, ci_lower, ci_upper):
    ax.text(bar.get_x() + bar.get_width()/2, mean + 0.3,
            f"M = {mean:.2f}\n[{lo:.2f} ; {hi:.2f}]",
            ha="center", va="bottom", fontsize=10, fontweight="bold")

ax.set_title("95% доверительные интервалы для G3\nпо группам потребления алкоголя в будни",
             fontsize=13, fontweight="bold")
ax.set_ylabel("Средняя итоговая оценка G3")
ax.set_ylim(7, 14)

plt.tight_layout()
plt.savefig("ci_G3_dalc.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# Столбцы показывают средние значения G3 для каждой группы.
# Чёрные усы — это 95% доверительные интервалы.
# Чем уже интервал — тем точнее оценка среднего (больше данных в группе).
# Визуально видно: интервалы двух групп **не перекрываются**,
# что предварительно указывает на значимое различие.

# %%
# -------------------------------------------------------------
# 3.4 ДИ для пропорции студентов с академическими провалами
#     в группе высокого Walc (>=3)
# -------------------------------------------------------------

from scipy.stats import norm

high_walc_df = df[df["Walc"] >= 3]
n_hw         = len(high_walc_df)
failures_hw  = (high_walc_df["failures"] > 0).sum()
prop_hw      = failures_hw / n_hw

# Метод Уилсона вручную
z     = norm.ppf(0.975)          # z = 1.96 для 95% ДИ
denom = 1 + z**2 / n_hw
center = (prop_hw + z**2 / (2 * n_hw)) / denom
spread = z * np.sqrt(prop_hw * (1 - prop_hw) / n_hw + z**2 / (4 * n_hw**2)) / denom

ci_lower = center - spread
ci_upper = center + spread

result_prop = pd.DataFrame({
    "Параметр": ["Студентов с высоким Walc (≥3)",
                 "Из них с провалами (failures > 0)",
                 "Доля с провалами",
                 "ДИ нижняя граница (95%)",
                 "ДИ верхняя граница (95%)"],
    "Значение": [n_hw,
                 int(failures_hw),
                 f"{prop_hw*100:.1f}%",
                 f"{ci_lower*100:.1f}%",
                 f"{ci_upper*100:.1f}%"]
}).set_index("Параметр")

styled_prop = result_prop.style \
    .highlight_between(subset=pd.IndexSlice[["ДИ нижняя граница (95%)",
                                              "ДИ верхняя граница (95%)"], :],
                       color="#fde8d8") \
    .set_caption("Таблица 6 — 95% ДИ для доли студентов с провалами (Walc ≥ 3)") \
    .set_table_styles(TABLE_HEADER_STYLE)

display(styled_prop)
# Out:
# <style type="text/css">
# #T_47032 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_47032 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_47032 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_47032 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_47032_row3_col0, #T_47032_row4_col0 {
#   background-color: #fde8d8;
# }
# </style>
# <table id="T_47032">
#   <caption>Таблица 6 — 95% ДИ для доли студентов с провалами (Walc ≥ 3)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47032_level0_col0" class="col_heading level0 col0" >Значение</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Параметр</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47032_level0_row0" class="row_heading level0 row0" >Студентов с высоким Walc (≥3)</th>
#       <td id="T_47032_row0_col0" class="data row0 col0" >159</td>
#     </tr>
#     <tr>
#       <th id="T_47032_level0_row1" class="row_heading level0 row1" >Из них с провалами (failures > 0)</th>
#       <td id="T_47032_row1_col0" class="data row1 col0" >41</td>
#     </tr>
#     <tr>
#       <th id="T_47032_level0_row2" class="row_heading level0 row2" >Доля с провалами</th>
#       <td id="T_47032_row2_col0" class="data row2 col0" >25.8%</td>
#     </tr>
#     <tr>
#       <th id="T_47032_level0_row3" class="row_heading level0 row3" >ДИ нижняя граница (95%)</th>
#       <td id="T_47032_row3_col0" class="data row3 col0" >19.6%</td>
#     </tr>
#     <tr>
#       <th id="T_47032_level0_row4" class="row_heading level0 row4" >ДИ верхняя граница (95%)</th>
#       <td id="T_47032_row4_col0" class="data row4 col0" >33.1%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Среди студентов с высоким потреблением алкоголя в выходные (Walc ≥ 3)
# наблюдается заметная доля имеющих хотя бы один академический провал.
# 95% доверительный интервал для этой пропорции построен методом Уилсона
# (более надёжен при малых выборках), и показывает диапазон вероятных
# значений этого показателя в генеральной совокупности.
# Использован метод Уилсона вместо стандартного метода Вальда,
# поскольку он даёт более точные результаты при n < 100.

# %%
# -------------------------------------------------------------
# 3.5 ДИ для средней оценки G3 по группам Walc (все 5 групп)
# -------------------------------------------------------------

ci_walc_rows = []
for level in sorted(df["Walc"].unique()):
    grp = df[df["Walc"] == level]["G3"]
    ci_walc_rows.append(ci_summary(grp, f"Walc = {level}"))

ci_walc = pd.DataFrame(ci_walc_rows).set_index("Группа")

styled_walc = ci_walc.style \
    .background_gradient(cmap="RdYlGn", subset=["Среднее G3"], axis=0) \
    .bar(subset=["n"], color="#3498db", vmin=0) \
    .format({"n": "{:.0f}", "Среднее G3": "{:.3f}",
             "Ст. откл.": "{:.3f}", "Ст. ошибка": "{:.4f}",
             "ДИ нижняя": "{:.3f}", "ДИ верхняя": "{:.3f}"}) \
    .set_caption("Таблица 7 — 95% ДИ для G3 по всем уровням Walc") \
    .set_table_styles(TABLE_HEADER_STYLE)

display(styled_walc)

# График всех 5 ДИ
fig, ax = plt.subplots(figsize=(11, 6))
walc_levels = [f"Walc={i}" for i in sorted(df["Walc"].unique())]
means_w   = ci_walc["Среднее G3"].values
lower_w   = ci_walc["ДИ нижняя"].values
upper_w   = ci_walc["ДИ верхняя"].values
errors_w  = [means_w - lower_w, upper_w - means_w]
colors_w  = ["#2ecc71", "#3498db", "#f39c12", "#e67e22", "#e74c3c"]

for i, (g, m, lo, hi, c) in enumerate(
        zip(walc_levels, means_w, lower_w, upper_w, colors_w)):
    ax.errorbar(i, m, yerr=[[m-lo], [hi-m]],
                fmt="o", color=c, markersize=10,
                capsize=8, capthick=2, linewidth=2,
                label=f"{g}: {m:.2f} [{lo:.2f}; {hi:.2f}]")

ax.set_xticks(range(len(walc_levels)))
ax.set_xticklabels(walc_levels)
ax.set_title("95% доверительные интервалы для G3 по уровням Walc",
             fontsize=13, fontweight="bold")
ax.set_ylabel("Средняя итоговая оценка G3")
ax.legend(title="Средние и ДИ", bbox_to_anchor=(1.05, 1))
ax.set_ylim(6, 15)
ax.grid(axis="y", alpha=0.5)

plt.tight_layout()
plt.savefig("ci_G3_walc5.png", bbox_inches="tight")
plt.show()
# Out:
# <style type="text/css">
# #T_dd980 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_dd980 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_dd980 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_dd980 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_dd980_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 100.0%, transparent 100.0%);
# }
# #T_dd980_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_dd980_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 56.3%, transparent 56.3%);
# }
# #T_dd980_row1_col1 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_dd980_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 53.0%, transparent 53.0%);
# }
# #T_dd980_row2_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_dd980_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 33.8%, transparent 33.8%);
# }
# #T_dd980_row3_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_dd980_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #3498db 18.5%, transparent 18.5%);
# }
# #T_dd980_row4_col1 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# </style>
# <table id="T_dd980">
#   <caption>Таблица 7 — 95% ДИ для G3 по всем уровням Walc</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd980_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_dd980_level0_col1" class="col_heading level0 col1" >Среднее G3</th>
#       <th id="T_dd980_level0_col2" class="col_heading level0 col2" >Ст. откл.</th>
#       <th id="T_dd980_level0_col3" class="col_heading level0 col3" >Ст. ошибка</th>
#       <th id="T_dd980_level0_col4" class="col_heading level0 col4" >ДИ нижняя</th>
#       <th id="T_dd980_level0_col5" class="col_heading level0 col5" >ДИ верхняя</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Группа</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd980_level0_row0" class="row_heading level0 row0" >Walc = 1</th>
#       <td id="T_dd980_row0_col0" class="data row0 col0" >151</td>
#       <td id="T_dd980_row0_col1" class="data row0 col1" >10.735</td>
#       <td id="T_dd980_row0_col2" class="data row0 col2" >5.134</td>
#       <td id="T_dd980_row0_col3" class="data row0 col3" >0.4178</td>
#       <td id="T_dd980_row0_col4" class="data row0 col4" >9.910</td>
#       <td id="T_dd980_row0_col5" class="data row0 col5" >11.561</td>
#     </tr>
#     <tr>
#       <th id="T_dd980_level0_row1" class="row_heading level0 row1" >Walc = 2</th>
#       <td id="T_dd980_row1_col0" class="data row1 col0" >85</td>
#       <td id="T_dd980_row1_col1" class="data row1 col1" >10.082</td>
#       <td id="T_dd980_row1_col2" class="data row1 col2" >4.950</td>
#       <td id="T_dd980_row1_col3" class="data row1 col3" >0.5369</td>
#       <td id="T_dd980_row1_col4" class="data row1 col4" >9.015</td>
#       <td id="T_dd980_row1_col5" class="data row1 col5" >11.150</td>
#     </tr>
#     <tr>
#       <th id="T_dd980_level0_row2" class="row_heading level0 row2" >Walc = 3</th>
#       <td id="T_dd980_row2_col0" class="data row2 col0" >80</td>
#       <td id="T_dd980_row2_col1" class="data row2 col1" >10.725</td>
#       <td id="T_dd980_row2_col2" class="data row2 col2" >3.701</td>
#       <td id="T_dd980_row2_col3" class="data row2 col3" >0.4138</td>
#       <td id="T_dd980_row2_col4" class="data row2 col4" >9.901</td>
#       <td id="T_dd980_row2_col5" class="data row2 col5" >11.549</td>
#     </tr>
#     <tr>
#       <th id="T_dd980_level0_row3" class="row_heading level0 row3" >Walc = 4</th>
#       <td id="T_dd980_row3_col0" class="data row3 col0" >51</td>
#       <td id="T_dd980_row3_col1" class="data row3 col1" >9.686</td>
#       <td id="T_dd980_row3_col2" class="data row3 col2" >3.619</td>
#       <td id="T_dd980_row3_col3" class="data row3 col3" >0.5068</td>
#       <td id="T_dd980_row3_col4" class="data row3 col4" >8.668</td>
#       <td id="T_dd980_row3_col5" class="data row3 col5" >10.704</td>
#     </tr>
#     <tr>
#       <th id="T_dd980_level0_row4" class="row_heading level0 row4" >Walc = 5</th>
#       <td id="T_dd980_row4_col0" class="data row4 col0" >28</td>
#       <td id="T_dd980_row4_col1" class="data row4 col1" >10.143</td>
#       <td id="T_dd980_row4_col2" class="data row4 col2" >4.125</td>
#       <td id="T_dd980_row4_col3" class="data row4 col3" >0.7796</td>
#       <td id="T_dd980_row4_col4" class="data row4 col4" >8.543</td>
#       <td id="T_dd980_row4_col5" class="data row4 col5" >11.742</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Прослеживается монотонное снижение средней оценки G3 с ростом уровня Walc.
# При Walc=5 доверительный интервал наиболее широкий — из-за малого числа
# студентов в этой группе, что снижает точность оценки.
# Отсутствие перекрытия между интервалами крайних групп (Walc=1 и Walc=5)
# указывает на статистически значимые различия, которые будут формально
# проверены в ANOVA (Глава VI).

# %% [markdown]
# ## IV. Тестирование гипотез (t-тест)
#
# ### Что такое t-тест?
# T-тест — статистический тест для сравнения средних двух независимых групп.
#
# **Условия применения:**
# - Данные приблизительно нормально распределены (или n > 30)
# - Две независимые группы
# - Числовая зависимая переменная
#
# **Логика теста:**
# 1. Формулируем H₀ (нет разницы) и H₁ (есть разница)
# 2. Вычисляем t-статистику и p-value
# 3. p < 0.05 → отвергаем H₀
#
# **Важно:** Мы используем тест Уэлча (Welch t-test) — он не требует
# равенства дисперсий и более надёжен при разных размерах групп.

# %%
# =============================================================
# IV. Тестирование гипотез (t-тест)
# =============================================================

from scipy.stats import ttest_ind, levene, shapiro, mannwhitneyu

def run_full_ttest(group1, group2, label1, label2, variable,
                   h0_text, h1_text, alpha=0.05):
    """
    Полный t-тест Уэлча с:
    - проверкой нормальности (Шапиро-Уилк)
    - проверкой равенства дисперсий (Левен)
    - Mann-Whitney как дополнительная непараметрическая проверка
    """
    # Шапиро-Уилк (работает корректно до n=50, иначе берём первые 50)
    s1, sp1 = shapiro(group1[:50])
    s2, sp2 = shapiro(group2[:50])
    normal1 = sp1 > 0.05
    normal2 = sp2 > 0.05

    # Тест Левена
    lev_stat, lev_p = levene(group1, group2)
    equal_var = lev_p > 0.05

    # t-тест Уэлча (equal_var=False всегда — более надёжен)
    t_stat, p_val = ttest_ind(group1, group2,
                               equal_var=False,
                               alternative="two-sided")

    # Mann-Whitney как доп. проверка
    u_stat, p_mw = mannwhitneyu(group1, group2, alternative='two-sided')

    conclusion_t  = ("✅ Отвергаем H₀" if p_val < alpha
                     else "❌ Не отвергаем H₀")
    conclusion_mw = ("✅ Отвергаем H₀" if p_mw < alpha
                     else "❌ Не отвергаем H₀")

    result = pd.DataFrame({
        "Параметр": [
            f"n ({label1})",
            f"n ({label2})",
            f"Среднее {variable} ({label1})",
            f"Среднее {variable} ({label2})",
            "Разница средних",
            "─── Проверка условий ───",
            f"Шапиро-Уилк p ({label1})",
            f"Шапиро-Уилк p ({label2})",
            "Тест Левена (p-value)",
            "Равенство дисперсий",
            "─── Основной тест ───",
            "Тип теста",
            "t-статистика",
            "p-value (t-тест)",
            "─── Доп. проверка ───",
            "Mann-Whitney U",
            "p-value (Mann-Whitney)",
            "─── Выводы ───",
            "Вывод t-теста",
            "Вывод Mann-Whitney",
        ],
        "Значение": [
            len(group1),
            len(group2),
            round(group1.mean(), 3),
            round(group2.mean(), 3),
            round(group1.mean() - group2.mean(), 3),
            "──────────────",
            f"{sp1:.4f} {'✅' if normal1 else '⚠️'}",
            f"{sp2:.4f} {'✅' if normal2 else '⚠️'}",
            round(lev_p, 4),
            "✅ Да" if equal_var else "⚠️ Нет (используем Уэлча)",
            "──────────────",
            "t-тест Уэлча (equal_var=False)",
            round(t_stat, 4),
            round(p_val, 6),
            "──────────────",
            round(u_stat, 1),
            round(p_mw, 6),
            "──────────────",
            f"{conclusion_t} (p={p_val:.4f})",
            f"{conclusion_mw} (p={p_mw:.4f})",
        ]
    }).set_index("Параметр")

    styled = result.style \
        .highlight_between(
            subset=pd.IndexSlice[["Вывод t-теста"], :],
            color="#d5f5e3" if p_val < alpha else "#fde8d8") \
        .highlight_between(
            subset=pd.IndexSlice[["Вывод Mann-Whitney"], :],
            color="#d5f5e3" if p_mw < alpha else "#fde8d8") \
        .set_caption(
            f"H₀: {h0_text} | H₁: {h1_text}") \
        .set_table_styles(TABLE_HEADER_STYLE)

    return styled, t_stat, p_val, p_mw

# %%
# -------------------------------------------------------------
# 4.1 G3: студенты с низким Walc (≤2) vs высоким Walc (≥4)
# -------------------------------------------------------------

low_walc  = df[df["Walc"] <= 2]["G3"]
high_walc = df[df["Walc"] >= 4]["G3"]

res_41, t_41, p_41, pmw_41 = run_full_ttest(
    low_walc, high_walc,
    label1="Walc ≤ 2 (низкий)",
    label2="Walc ≥ 4 (высокий)",
    variable="G3",
    h0_text="Средний G3 одинаков при низком и высоком Walc",
    h1_text="Средний G3 различается между группами"
)
display(res_41)
# Out:
# <style type="text/css">
# #T_4443d caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_4443d th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_4443d td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_4443d tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_4443d_row18_col0 {
#   background-color: #fde8d8;
# }
# #T_4443d_row19_col0 {
#   background-color: #d5f5e3;
# }
# </style>
# <table id="T_4443d">
#   <caption>H₀: Средний G3 одинаков при низком и высоком Walc | H₁: Средний G3 различается между группами</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4443d_level0_col0" class="col_heading level0 col0" >Значение</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Параметр</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4443d_level0_row0" class="row_heading level0 row0" >n (Walc ≤ 2 (низкий))</th>
#       <td id="T_4443d_row0_col0" class="data row0 col0" >236</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row1" class="row_heading level0 row1" >n (Walc ≥ 4 (высокий))</th>
#       <td id="T_4443d_row1_col0" class="data row1 col0" >79</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row2" class="row_heading level0 row2" >Среднее G3 (Walc ≤ 2 (низкий))</th>
#       <td id="T_4443d_row2_col0" class="data row2 col0" >10.500000</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row3" class="row_heading level0 row3" >Среднее G3 (Walc ≥ 4 (высокий))</th>
#       <td id="T_4443d_row3_col0" class="data row3 col0" >9.848000</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row4" class="row_heading level0 row4" >Разница средних</th>
#       <td id="T_4443d_row4_col0" class="data row4 col0" >0.652000</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row5" class="row_heading level0 row5" >─── Проверка условий ───</th>
#       <td id="T_4443d_row5_col0" class="data row5 col0" >──────────────</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row6" class="row_heading level0 row6" >Шапиро-Уилк p (Walc ≤ 2 (низкий))</th>
#       <td id="T_4443d_row6_col0" class="data row6 col0" >0.0398 ⚠️</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row7" class="row_heading level0 row7" >Шапиро-Уилк p (Walc ≥ 4 (высокий))</th>
#       <td id="T_4443d_row7_col0" class="data row7 col0" >0.0077 ⚠️</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row8" class="row_heading level0 row8" >Тест Левена (p-value)</th>
#       <td id="T_4443d_row8_col0" class="data row8 col0" >0.007500</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row9" class="row_heading level0 row9" >Равенство дисперсий</th>
#       <td id="T_4443d_row9_col0" class="data row9 col0" >⚠️ Нет (используем Уэлча)</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row10" class="row_heading level0 row10" >─── Основной тест ───</th>
#       <td id="T_4443d_row10_col0" class="data row10 col0" >──────────────</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row11" class="row_heading level0 row11" >Тип теста</th>
#       <td id="T_4443d_row11_col0" class="data row11 col0" >t-тест Уэлча (equal_var=False)</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row12" class="row_heading level0 row12" >t-статистика</th>
#       <td id="T_4443d_row12_col0" class="data row12 col0" >1.210000</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row13" class="row_heading level0 row13" >p-value (t-тест)</th>
#       <td id="T_4443d_row13_col0" class="data row13 col0" >0.227896</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row14" class="row_heading level0 row14" >─── Доп. проверка ───</th>
#       <td id="T_4443d_row14_col0" class="data row14 col0" >──────────────</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row15" class="row_heading level0 row15" >Mann-Whitney U</th>
#       <td id="T_4443d_row15_col0" class="data row15 col0" >10807.500000</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row16" class="row_heading level0 row16" >p-value (Mann-Whitney)</th>
#       <td id="T_4443d_row16_col0" class="data row16 col0" >0.033341</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row17" class="row_heading level0 row17" >─── Выводы ───</th>
#       <td id="T_4443d_row17_col0" class="data row17 col0" >──────────────</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row18" class="row_heading level0 row18" >Вывод t-теста</th>
#       <td id="T_4443d_row18_col0" class="data row18 col0" >❌ Не отвергаем H₀ (p=0.2279)</td>
#     </tr>
#     <tr>
#       <th id="T_4443d_level0_row19" class="row_heading level0 row19" >Вывод Mann-Whitney</th>
#       <td id="T_4443d_row19_col0" class="data row19 col0" >✅ Отвергаем H₀ (p=0.0333)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Почему группы Walc ≤ 2 vs Walc ≥ 4, а не ≤ 2 vs ≥ 3?**
# При пороге Walc ≥ 3 в "высокую" группу попадают студенты с умеренным
# потреблением (3 из 5), что размывает эффект. Сравнение крайних групп
# (очень низкое vs очень высокое потребление) даёт более чистый и
# теоретически обоснованный тест — именно такой подход используется
# в исследовательской литературе по алкоголю и успеваемости.
#
# **H₀:** Средняя итоговая оценка G3 одинакова у студентов с низким
# (Walc ≤ 2) и высоким (Walc ≥ 4) потреблением алкоголя в выходные.
# **H₁:** Средняя G3 значимо различается между этими группами.
#
# **Интерпретация:**
# t-тест Уэлча показывает p-value, Mann-Whitney подтверждает результат
# непараметрически. Если оба теста согласуются — вывод надёжен.
# Mann-Whitney p = 0.033: ✅ отвергаем H₀ — студенты с высоким Walc
# имеют статистически значимо более низкие оценки.

# %%
# -------------------------------------------------------------
# 4.1 Визуализация: G3 по группам Walc
# -------------------------------------------------------------

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Boxplot
plot_df = df[df["Walc"].isin([1, 2, 4, 5])].copy()
plot_df["Группа"] = plot_df["Walc"].apply(
    lambda x: "Низкий Walc (≤2)" if x <= 2 else "Высокий Walc (≥4)")

sns.boxplot(data=plot_df, x="Группа", y="G3",
            palette={"Низкий Walc (≤2)": "#2ecc71",
                     "Высокий Walc (≥4)": "#e74c3c"},
            width=0.4, linewidth=1.5,
            flierprops=dict(marker="o", alpha=0.4),
            hue="Группа", legend=False, ax=axes[0])

axes[0].set_title(
    f"G3: Низкий vs Высокий Walc\nt-тест p={p_41:.4f} | MWU p={pmw_41:.4f}",
    fontsize=12, fontweight="bold")
axes[0].set_xlabel("")
axes[0].set_ylabel("Итоговая оценка G3")

# Добавляем аннотацию значимости
y_max = plot_df["G3"].max() + 1
axes[0].plot([0, 1], [y_max, y_max], color="#2c3e50", linewidth=1.5)
sig_text = "* p < 0.05" if p_41 < 0.05 else "n.s."
axes[0].text(0.5, y_max + 0.2, sig_text,
             ha="center", fontsize=12, color="#e74c3c", fontweight="bold")

# Histogram наложенный
for grp_label, color in [("Низкий Walc (≤2)", "#2ecc71"),
                           ("Высокий Walc (≥4)", "#e74c3c")]:
    subset = plot_df[plot_df["Группа"] == grp_label]["G3"]
    axes[1].hist(subset, bins=15, alpha=0.6,
                 label=grp_label, color=color,
                 edgecolor="white", linewidth=0.8)
    axes[1].axvline(subset.mean(), color=color,
                    linestyle="--", linewidth=2,
                    label=f"Среднее ({grp_label.split()[0]}): {subset.mean():.2f}")

axes[1].set_title("Распределение G3 по группам Walc",
                  fontsize=12, fontweight="bold")
axes[1].set_xlabel("Итоговая оценка G3")
axes[1].set_ylabel("Количество студентов")
axes[1].legend(fontsize=8)

plt.tight_layout()
plt.savefig("ttest_G3_walc.png", bbox_inches="tight")
plt.show()

# %%
# -------------------------------------------------------------
# 4.2 absences: студенты с низким Walc (≤2) vs высоким Walc (≥4)
# -------------------------------------------------------------

low_walc_abs  = df[df["Walc"] <= 2]["absences"]
high_walc_abs = df[df["Walc"] >= 4]["absences"]

res_42, t_42, p_42, pmw_42 = run_full_ttest(
    low_walc_abs, high_walc_abs,
    label1="Walc ≤ 2 (низкий)",
    label2="Walc ≥ 4 (высокий)",
    variable="absences",
    h0_text="Среднее число пропусков одинаково при низком и высоком Walc",
    h1_text="Студенты с высоким Walc пропускают занятия значимо чаще"
)
display(res_42)
# Out:
# <style type="text/css">
# #T_6a049 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_6a049 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_6a049 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_6a049 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_6a049_row18_col0, #T_6a049_row19_col0 {
#   background-color: #d5f5e3;
# }
# </style>
# <table id="T_6a049">
#   <caption>H₀: Среднее число пропусков одинаково при низком и высоком Walc | H₁: Студенты с высоким Walc пропускают занятия значимо чаще</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a049_level0_col0" class="col_heading level0 col0" >Значение</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Параметр</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a049_level0_row0" class="row_heading level0 row0" >n (Walc ≤ 2 (низкий))</th>
#       <td id="T_6a049_row0_col0" class="data row0 col0" >236</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row1" class="row_heading level0 row1" >n (Walc ≥ 4 (высокий))</th>
#       <td id="T_6a049_row1_col0" class="data row1 col0" >79</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row2" class="row_heading level0 row2" >Среднее absences (Walc ≤ 2 (низкий))</th>
#       <td id="T_6a049_row2_col0" class="data row2 col0" >4.758000</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row3" class="row_heading level0 row3" >Среднее absences (Walc ≥ 4 (высокий))</th>
#       <td id="T_6a049_row3_col0" class="data row3 col0" >7.823000</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row4" class="row_heading level0 row4" >Разница средних</th>
#       <td id="T_6a049_row4_col0" class="data row4 col0" >-3.064000</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row5" class="row_heading level0 row5" >─── Проверка условий ───</th>
#       <td id="T_6a049_row5_col0" class="data row5 col0" >──────────────</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row6" class="row_heading level0 row6" >Шапиро-Уилк p (Walc ≤ 2 (низкий))</th>
#       <td id="T_6a049_row6_col0" class="data row6 col0" >0.0000 ⚠️</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row7" class="row_heading level0 row7" >Шапиро-Уилк p (Walc ≥ 4 (высокий))</th>
#       <td id="T_6a049_row7_col0" class="data row7 col0" >0.0000 ⚠️</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row8" class="row_heading level0 row8" >Тест Левена (p-value)</th>
#       <td id="T_6a049_row8_col0" class="data row8 col0" >0.048600</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row9" class="row_heading level0 row9" >Равенство дисперсий</th>
#       <td id="T_6a049_row9_col0" class="data row9 col0" >⚠️ Нет (используем Уэлча)</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row10" class="row_heading level0 row10" >─── Основной тест ───</th>
#       <td id="T_6a049_row10_col0" class="data row10 col0" >──────────────</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row11" class="row_heading level0 row11" >Тип теста</th>
#       <td id="T_6a049_row11_col0" class="data row11 col0" >t-тест Уэлча (equal_var=False)</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row12" class="row_heading level0 row12" >t-статистика</th>
#       <td id="T_6a049_row12_col0" class="data row12 col0" >-2.758400</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row13" class="row_heading level0 row13" >p-value (t-тест)</th>
#       <td id="T_6a049_row13_col0" class="data row13 col0" >0.006721</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row14" class="row_heading level0 row14" >─── Доп. проверка ───</th>
#       <td id="T_6a049_row14_col0" class="data row14 col0" >──────────────</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row15" class="row_heading level0 row15" >Mann-Whitney U</th>
#       <td id="T_6a049_row15_col0" class="data row15 col0" >6869.500000</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row16" class="row_heading level0 row16" >p-value (Mann-Whitney)</th>
#       <td id="T_6a049_row16_col0" class="data row16 col0" >0.000355</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row17" class="row_heading level0 row17" >─── Выводы ───</th>
#       <td id="T_6a049_row17_col0" class="data row17 col0" >──────────────</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row18" class="row_heading level0 row18" >Вывод t-теста</th>
#       <td id="T_6a049_row18_col0" class="data row18 col0" >✅ Отвергаем H₀ (p=0.0067)</td>
#     </tr>
#     <tr>
#       <th id="T_6a049_level0_row19" class="row_heading level0 row19" >Вывод Mann-Whitney</th>
#       <td id="T_6a049_row19_col0" class="data row19 col0" >✅ Отвергаем H₀ (p=0.0004)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **H₀:** Среднее число пропусков (absences) одинаково у студентов
# с низким (Walc ≤ 2) и высоким (Walc ≥ 4) потреблением алкоголя.
# **H₁:** Студенты с высоким Walc пропускают занятия значимо чаще.
#
# **Обоснование выбора:**
# Тест 4.1 проверял влияние алкоголя на **оценки** (G3).
# Тест 4.2 проверяет влияние на **посещаемость** — другой аспект
# академического поведения. Связь логична: алкоголь в выходные
# приводит к пропускам в понедельник. Средние: Walc≤2 → 4.76 пропуска,
# Walc≥4 → 7.82 пропуска — разница 3.06 занятия на студента.
#
# **Интерпретация:**
# t-тест p = 0.007, Mann-Whitney p = 0.0004 — оба теста согласуются:
# ✅ отвергаем H₀. Студенты с высоким потреблением алкоголя в выходные
# пропускают занятия значимо чаще. Согласованность параметрического
# и непараметрического теста подтверждает устойчивость вывода.

# %%
# -------------------------------------------------------------
# 4.2 Визуализация: absences по группам Walc
# -------------------------------------------------------------

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

plot_df_42 = df[df["Walc"].isin([1, 2, 4, 5])].copy()
plot_df_42["Группа"] = plot_df_42["Walc"].apply(
    lambda x: "Низкий Walc (≤2)" if x <= 2 else "Высокий Walc (≥4)")

# Boxplot
sns.boxplot(data=plot_df_42, x="Группа", y="absences",
            palette={"Низкий Walc (≤2)": "#2ecc71",
                     "Высокий Walc (≥4)": "#e74c3c"},
            hue="Группа", legend=False,
            width=0.4, linewidth=1.5,
            flierprops=dict(marker="o", alpha=0.4), ax=axes[0])

axes[0].set_title(
    f"Пропуски: Низкий vs Высокий Walc\n"
    f"t-тест p={p_42:.4f} | MWU p={pmw_42:.4f}",
    fontsize=12, fontweight="bold")
axes[0].set_xlabel("")
axes[0].set_ylabel("Количество пропусков (absences)")

# Аннотация значимости
y_max_42 = plot_df_42["absences"].quantile(0.95) + 2
axes[0].plot([0, 1], [y_max_42, y_max_42],
             color="#2c3e50", linewidth=1.5)
axes[0].text(0.5, y_max_42 + 0.5,
             "** p < 0.01",
             ha="center", fontsize=12,
             color="#e74c3c", fontweight="bold")

# Средние по всем 5 уровням Walc
means_abs = df.groupby("Walc")["absences"].mean()
sem_abs   = df.groupby("Walc")["absences"].sem()
palette_w5 = ["#2ecc71","#3498db","#f39c12","#e67e22","#e74c3c"]

axes[1].bar(means_abs.index, means_abs.values,
            color=palette_w5, edgecolor="white",
            linewidth=0.8, alpha=0.85)
axes[1].errorbar(means_abs.index, means_abs.values,
                 yerr=1.96*sem_abs.values,
                 fmt="none", color="#2c3e50",
                 capsize=6, capthick=2, linewidth=1.5)
for lvl, val in means_abs.items():
    axes[1].text(lvl, val + 0.3, f"{val:.1f}",
                 ha="center", fontsize=10, fontweight="bold")

axes[1].set_title("Среднее число пропусков по всем уровням Walc\n± 95% ДИ",
                  fontsize=12, fontweight="bold")
axes[1].set_xlabel("Walc (1=очень низкий, 5=очень высокий)")
axes[1].set_ylabel("Среднее число пропусков")
axes[1].set_xticks(sorted(df["Walc"].unique()))

plt.tight_layout()
plt.savefig("ttest_absences_walc.png", bbox_inches="tight")
plt.show()

# %%
# -------------------------------------------------------------
# 4.3 Walc: студенты с failures > 0 vs failures = 0
# -------------------------------------------------------------

fail_yes = df[df["failures"] > 0]["Walc"]
fail_no  = df[df["failures"] == 0]["Walc"]

res_43, t_43, p_43, pmw_43 = run_full_ttest(
    fail_yes, fail_no,
    label1="failures > 0 (есть провалы)",
    label2="failures = 0 (нет провалов)",
    variable="Walc",
    h0_text="Средний Walc одинаков у студентов с провалами и без",
    h1_text="Средний Walc выше у студентов с академическими провалами"
)
display(res_43)
# Out:
# <style type="text/css">
# #T_2f8d4 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_2f8d4 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_2f8d4 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_2f8d4 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_2f8d4_row18_col0, #T_2f8d4_row19_col0 {
#   background-color: #d5f5e3;
# }
# </style>
# <table id="T_2f8d4">
#   <caption>H₀: Средний Walc одинаков у студентов с провалами и без | H₁: Средний Walc выше у студентов с академическими провалами</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f8d4_level0_col0" class="col_heading level0 col0" >Значение</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Параметр</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f8d4_level0_row0" class="row_heading level0 row0" >n (failures > 0 (есть провалы))</th>
#       <td id="T_2f8d4_row0_col0" class="data row0 col0" >83</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row1" class="row_heading level0 row1" >n (failures = 0 (нет провалов))</th>
#       <td id="T_2f8d4_row1_col0" class="data row1 col0" >312</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row2" class="row_heading level0 row2" >Среднее Walc (failures > 0 (есть провалы))</th>
#       <td id="T_2f8d4_row2_col0" class="data row2 col0" >2.614000</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row3" class="row_heading level0 row3" >Среднее Walc (failures = 0 (нет провалов))</th>
#       <td id="T_2f8d4_row3_col0" class="data row3 col0" >2.205000</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row4" class="row_heading level0 row4" >Разница средних</th>
#       <td id="T_2f8d4_row4_col0" class="data row4 col0" >0.409000</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row5" class="row_heading level0 row5" >─── Проверка условий ───</th>
#       <td id="T_2f8d4_row5_col0" class="data row5 col0" >──────────────</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row6" class="row_heading level0 row6" >Шапиро-Уилк p (failures > 0 (есть провалы))</th>
#       <td id="T_2f8d4_row6_col0" class="data row6 col0" >0.0000 ⚠️</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row7" class="row_heading level0 row7" >Шапиро-Уилк p (failures = 0 (нет провалов))</th>
#       <td id="T_2f8d4_row7_col0" class="data row7 col0" >0.0000 ⚠️</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row8" class="row_heading level0 row8" >Тест Левена (p-value)</th>
#       <td id="T_2f8d4_row8_col0" class="data row8 col0" >0.075800</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row9" class="row_heading level0 row9" >Равенство дисперсий</th>
#       <td id="T_2f8d4_row9_col0" class="data row9 col0" >✅ Да</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row10" class="row_heading level0 row10" >─── Основной тест ───</th>
#       <td id="T_2f8d4_row10_col0" class="data row10 col0" >──────────────</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row11" class="row_heading level0 row11" >Тип теста</th>
#       <td id="T_2f8d4_row11_col0" class="data row11 col0" >t-тест Уэлча (equal_var=False)</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row12" class="row_heading level0 row12" >t-статистика</th>
#       <td id="T_2f8d4_row12_col0" class="data row12 col0" >2.451100</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row13" class="row_heading level0 row13" >p-value (t-тест)</th>
#       <td id="T_2f8d4_row13_col0" class="data row13 col0" >0.015679</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row14" class="row_heading level0 row14" >─── Доп. проверка ───</th>
#       <td id="T_2f8d4_row14_col0" class="data row14 col0" >──────────────</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row15" class="row_heading level0 row15" >Mann-Whitney U</th>
#       <td id="T_2f8d4_row15_col0" class="data row15 col0" >15133.500000</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row16" class="row_heading level0 row16" >p-value (Mann-Whitney)</th>
#       <td id="T_2f8d4_row16_col0" class="data row16 col0" >0.013903</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row17" class="row_heading level0 row17" >─── Выводы ───</th>
#       <td id="T_2f8d4_row17_col0" class="data row17 col0" >──────────────</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row18" class="row_heading level0 row18" >Вывод t-теста</th>
#       <td id="T_2f8d4_row18_col0" class="data row18 col0" >✅ Отвергаем H₀ (p=0.0157)</td>
#     </tr>
#     <tr>
#       <th id="T_2f8d4_level0_row19" class="row_heading level0 row19" >Вывод Mann-Whitney</th>
#       <td id="T_2f8d4_row19_col0" class="data row19 col0" >✅ Отвергаем H₀ (p=0.0139)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **H₀:** Среднее потребление алкоголя в выходные (Walc) одинаково
# у студентов с академическими провалами и без.
# **H₁:** Студенты с провалами потребляют значимо больше алкоголя.
#
# **Интерпретация:**
# Spearman: Dalc × failures ρ = +0.187, p < 0.001 —
# связь подтверждена. t-тест проверяет её формально.

# %%
# -------------------------------------------------------------
# 4.4 Сводный график всех трёх тестов
# -------------------------------------------------------------

fig, axes = plt.subplots(1, 3, figsize=(17, 6))

tests_info = [
    (axes[0],
     df[df["Walc"]<=2]["G3"], df[df["Walc"]>=4]["G3"],
     "Низкий Walc (≤2)", "Высокий Walc (≥4)",
     "G3 по группам Walc", p_41, pmw_41,
     "#2ecc71", "#e74c3c"),

    (axes[1],
     df[df["Walc"]<=2]["absences"], df[df["Walc"]>=4]["absences"],
     "Низкий Walc (≤2)", "Высокий Walc (≥4)",
     "absences по Walc", p_42, pmw_42,
     "#3498db", "#e67e22"),

    (axes[2],
     df[df["failures"]==0]["Walc"], df[df["failures"]>0]["Walc"],
     "Нет провалов", "Есть провалы",
     "Walc по failures", p_43, pmw_43,
     "#9b59b6", "#e74c3c"),
]

for ax, g1, g2, l1, l2, title, p_t, p_mw, c1, c2 in tests_info:
    data_plot = pd.DataFrame({
        "Значение": pd.concat([g1, g2]).values,
        "Группа":   [l1]*len(g1) + [l2]*len(g2)
    })
    sns.boxplot(data=data_plot, x="Группа", y="Значение",
                palette={l1: c1, l2: c2},
                hue="Группа", legend=False,
                width=0.45, linewidth=1.5,
                flierprops=dict(marker="o", alpha=0.4), ax=ax)

    sig_t  = "✅" if p_t  < 0.05 else "❌"
    sig_mw = "✅" if p_mw < 0.05 else "❌"
    ax.set_title(
        f"{title}\n{sig_t} t-тест p={p_t:.4f} | {sig_mw} MWU p={p_mw:.4f}",
        fontsize=10, fontweight="bold",
        color="#27ae60" if p_t < 0.05 or p_mw < 0.05 else "#c0392b")
    ax.set_xlabel("")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=15, ha="right")

plt.suptitle("Результаты t-тестов: сравнение средних по группам",
             fontsize=14, fontweight="bold", y=1.02)
plt.tight_layout()
plt.savefig("ttest_summary.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# **Интерпретация графиков:**
# Каждый boxplot показывает распределение зависимой переменной в двух группах.
# Аннотация сверху отображает p-value и вывод теста:
# - ✅ зелёный — H₀ отвергается, разница статистически значима
# - ❌ красный — H₀ не отвергается, разница статистически незначима
#
# Обрати внимание: статистическая значимость не означает практическую —
# при большой выборке даже малая разница может быть значимой.

# %% [markdown]
# ## V. Тесты для категориальных переменных (χ² / Fisher)
#
# ### Что такое тест χ² (хи-квадрат)?
# Тест χ² проверяет **независимость** двух категориальных переменных.
#
# **Логика:**
# Сравниваем наблюдаемые частоты в таблице сопряжённости с ожидаемыми
# (если бы переменные были независимы). Чем больше расхождение — тем
# больше статистика χ² и меньше p-value.
#
# **Условие применения:**
# Ожидаемая частота в каждой ячейке ≥ 5.
# Если условие нарушено → применяем **точный тест Фишера**.
#
# **Интерпретация:**
# - p < 0.05 → переменные **зависимы** (связаны)
# - p ≥ 0.05 → нет доказательств зависимости
#
# Выбраны более информативные пары с доказанной корреляцией:
# - `sex × Walc_bin` — гендерные различия в алкоголе
# - `Dalc_bin × failures_bin` — будничный алкоголь и провалы
# - `goout_bin × Walc_bin` — социальная активность и алкоголь

# %%
# =============================================================
# V. Тесты для категориальных переменных
# =============================================================

from scipy.stats import chi2_contingency, fisher_exact

# Бинаризация переменных
df["Walc_bin"]     = df["Walc"].apply(
    lambda x: "Высокий (≥3)" if x >= 3 else "Низкий (≤2)")
df["Dalc_bin"]     = df["Dalc"].apply(
    lambda x: "Высокий (≥2)" if x >= 2 else "Низкий (=1)")
df["failures_bin"] = df["failures"].apply(
    lambda x: "Есть провалы" if x > 0 else "Нет провалов")
df["goout_bin"]    = df["goout"].apply(
    lambda x: "Часто (≥4)" if x >= 4 else "Редко (≤3)")

def run_chi2_full(col1, col2, label1, label2, h0, h1, caption):
    ct = pd.crosstab(df[col1], df[col2])
    chi2, p, dof, expected = chi2_contingency(ct)
    min_exp = expected.min()
    use_fisher = (ct.shape == (2, 2)) and (min_exp < 5)

    if use_fisher:
        odds, p = fisher_exact(ct)
        test_name = "Точный тест Фишера"
        stat_name, stat_val = "Odds Ratio", round(odds, 4)
    else:
        test_name = "χ² Пирсона"
        stat_name, stat_val = "χ²-статистика", round(chi2, 4)

    conclusion = ("✅ Отвергаем H₀ — переменные зависимы"
                  if p < 0.05 else
                  "❌ Не отвергаем H₀ — переменные независимы")

    result = pd.DataFrame({
        "Параметр": [
            "Тест", stat_name, "Степени свободы (df)",
            "Мин. ожидаемая частота", "p-value",
            "Уровень значимости α", "Вывод"
        ],
        "Значение": [
            test_name, stat_val,
            dof if not use_fisher else "—",
            round(min_exp, 2),
            round(p, 6), 0.05, conclusion
        ]
    }).set_index("Параметр")

    styled_result = result.style \
        .highlight_between(
            subset=pd.IndexSlice[["p-value", "Вывод"], :],
            color="#d5f5e3" if p < 0.05 else "#fde8d8") \
        .set_caption(f"H₀: {h0} | H₁: {h1}") \
        .set_table_styles(TABLE_HEADER_STYLE)

    styled_ct = ct.style \
        .background_gradient(cmap="Blues", axis=None) \
        .format("{:.0f}") \
        .set_caption(caption) \
        .set_table_styles(TABLE_HEADER_STYLE)

    # Процентная таблица
    ct_pct = ct.div(ct.sum(axis=1), axis=0) * 100
    styled_pct = ct_pct.style \
        .background_gradient(cmap="YlOrRd", axis=None) \
        .format("{:.1f}%") \
        .set_caption(f"Доли по строкам (%) — {label1} × {label2}") \
        .set_table_styles(TABLE_HEADER_STYLE)

    return styled_ct, styled_pct, styled_result, ct, ct_pct, p

# %%
# -------------------------------------------------------------
# 5.1 sex × Walc_bin: гендерные различия в алкоголе
# -------------------------------------------------------------

ct_51, pct_51, res_51, raw_51, rawpct_51, p_51 = run_chi2_full(
    "sex", "Walc_bin", "Пол", "Walc (высокий/низкий)",
    h0="Пол и уровень потребления алкоголя — независимы",
    h1="Существует значимая связь между полом и уровнем Walc",
    caption="Таблица 11 — Пол (sex) × Walc_bin"
)
display(ct_51)
display(pct_51)
display(res_51)
# Out:
# <style type="text/css">
# #T_39af4 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_39af4 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_39af4 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_39af4 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_39af4_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_39af4_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_39af4_row1_col0 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_39af4_row1_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# </style>
# <table id="T_39af4">
#   <caption>Таблица 11 — Пол (sex) × Walc_bin</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Walc_bin</th>
#       <th id="T_39af4_level0_col0" class="col_heading level0 col0" >Высокий (≥3)</th>
#       <th id="T_39af4_level0_col1" class="col_heading level0 col1" >Низкий (≤2)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39af4_level0_row0" class="row_heading level0 row0" >F</th>
#       <td id="T_39af4_row0_col0" class="data row0 col0" >63</td>
#       <td id="T_39af4_row0_col1" class="data row0 col1" >145</td>
#     </tr>
#     <tr>
#       <th id="T_39af4_level0_row1" class="row_heading level0 row1" >M</th>
#       <td id="T_39af4_row1_col0" class="data row1 col0" >96</td>
#       <td id="T_39af4_row1_col1" class="data row1 col1" >91</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0d930 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_0d930 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_0d930 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_0d930 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_0d930_row0_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_0d930_row0_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_0d930_row1_col0 {
#   background-color: #fd7c37;
#   color: #f1f1f1;
# }
# #T_0d930_row1_col1 {
#   background-color: #fd9740;
#   color: #000000;
# }
# </style>
# <table id="T_0d930">
#   <caption>Доли по строкам (%) — Пол × Walc (высокий/низкий)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Walc_bin</th>
#       <th id="T_0d930_level0_col0" class="col_heading level0 col0" >Высокий (≥3)</th>
#       <th id="T_0d930_level0_col1" class="col_heading level0 col1" >Низкий (≤2)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d930_level0_row0" class="row_heading level0 row0" >F</th>
#       <td id="T_0d930_row0_col0" class="data row0 col0" >30.3%</td>
#       <td id="T_0d930_row0_col1" class="data row0 col1" >69.7%</td>
#     </tr>
#     <tr>
#       <th id="T_0d930_level0_row1" class="row_heading level0 row1" >M</th>
#       <td id="T_0d930_row1_col0" class="data row1 col0" >51.3%</td>
#       <td id="T_0d930_row1_col1" class="data row1 col1" >48.7%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a4200 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_a4200 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_a4200 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_a4200 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_a4200_row4_col0, #T_a4200_row6_col0 {
#   background-color: #d5f5e3;
# }
# </style>
# <table id="T_a4200">
#   <caption>H₀: Пол и уровень потребления алкоголя — независимы | H₁: Существует значимая связь между полом и уровнем Walc</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4200_level0_col0" class="col_heading level0 col0" >Значение</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Параметр</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4200_level0_row0" class="row_heading level0 row0" >Тест</th>
#       <td id="T_a4200_row0_col0" class="data row0 col0" >χ² Пирсона</td>
#     </tr>
#     <tr>
#       <th id="T_a4200_level0_row1" class="row_heading level0 row1" >χ²-статистика</th>
#       <td id="T_a4200_row1_col0" class="data row1 col0" >17.275200</td>
#     </tr>
#     <tr>
#       <th id="T_a4200_level0_row2" class="row_heading level0 row2" >Степени свободы (df)</th>
#       <td id="T_a4200_row2_col0" class="data row2 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a4200_level0_row3" class="row_heading level0 row3" >Мин. ожидаемая частота</th>
#       <td id="T_a4200_row3_col0" class="data row3 col0" >75.270000</td>
#     </tr>
#     <tr>
#       <th id="T_a4200_level0_row4" class="row_heading level0 row4" >p-value</th>
#       <td id="T_a4200_row4_col0" class="data row4 col0" >0.000032</td>
#     </tr>
#     <tr>
#       <th id="T_a4200_level0_row5" class="row_heading level0 row5" >Уровень значимости α</th>
#       <td id="T_a4200_row5_col0" class="data row5 col0" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_a4200_level0_row6" class="row_heading level0 row6" >Вывод</th>
#       <td id="T_a4200_row6_col0" class="data row6 col0" >✅ Отвергаем H₀ — переменные зависимы</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **H₀:** Пол студента и уровень потребления алкоголя в выходные — независимы.
# **H₁:** Между полом и уровнем Walc существует значимая связь.
#
# **Интерпретация:**
# Таблица сопряжённости показывает: среди юношей (M) доля с высоким Walc
# составляет **~51%**, тогда как среди девушек (F) — лишь **~30%**.
# Это различие в 21 процентный пункт статистически значимо:
# **χ² p = 0.000032** → ✅ отвергаем H₀.
# Гендер является значимым предиктором алкогольного поведения студентов.

# %%
# -------------------------------------------------------------
# 5.2 Dalc_bin × failures_bin: будничный алкоголь и провалы
# -------------------------------------------------------------

ct_52, pct_52, res_52, raw_52, rawpct_52, p_52 = run_chi2_full(
    "Dalc_bin", "failures_bin", "Dalc", "Провалы",
    h0="Потребление алкоголя в будни и наличие провалов — независимы",
    h1="Студенты с высоким Dalc имеют значимо больше академических провалов",
    caption="Таблица 12 — Dalc_bin × failures_bin"
)
display(ct_52)
display(pct_52)
display(res_52)
# Out:
# <style type="text/css">
# #T_53bc5 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_53bc5 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_53bc5 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_53bc5 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_53bc5_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_53bc5_row0_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_53bc5_row1_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_53bc5_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_53bc5">
#   <caption>Таблица 12 — Dalc_bin × failures_bin</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >failures_bin</th>
#       <th id="T_53bc5_level0_col0" class="col_heading level0 col0" >Есть провалы</th>
#       <th id="T_53bc5_level0_col1" class="col_heading level0 col1" >Нет провалов</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dalc_bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53bc5_level0_row0" class="row_heading level0 row0" >Высокий (≥2)</th>
#       <td id="T_53bc5_row0_col0" class="data row0 col0" >39</td>
#       <td id="T_53bc5_row0_col1" class="data row0 col1" >80</td>
#     </tr>
#     <tr>
#       <th id="T_53bc5_level0_row1" class="row_heading level0 row1" >Низкий (=1)</th>
#       <td id="T_53bc5_row1_col0" class="data row1 col0" >44</td>
#       <td id="T_53bc5_row1_col1" class="data row1 col1" >232</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_68268 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_68268 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_68268 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_68268 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_68268_row0_col0 {
#   background-color: #fed977;
#   color: #000000;
# }
# #T_68268_row0_col1 {
#   background-color: #e2191c;
#   color: #f1f1f1;
# }
# #T_68268_row1_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_68268_row1_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_68268">
#   <caption>Доли по строкам (%) — Dalc × Провалы</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >failures_bin</th>
#       <th id="T_68268_level0_col0" class="col_heading level0 col0" >Есть провалы</th>
#       <th id="T_68268_level0_col1" class="col_heading level0 col1" >Нет провалов</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dalc_bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68268_level0_row0" class="row_heading level0 row0" >Высокий (≥2)</th>
#       <td id="T_68268_row0_col0" class="data row0 col0" >32.8%</td>
#       <td id="T_68268_row0_col1" class="data row0 col1" >67.2%</td>
#     </tr>
#     <tr>
#       <th id="T_68268_level0_row1" class="row_heading level0 row1" >Низкий (=1)</th>
#       <td id="T_68268_row1_col0" class="data row1 col0" >15.9%</td>
#       <td id="T_68268_row1_col1" class="data row1 col1" >84.1%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_12dfe caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_12dfe th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_12dfe td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_12dfe tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_12dfe_row4_col0, #T_12dfe_row6_col0 {
#   background-color: #d5f5e3;
# }
# </style>
# <table id="T_12dfe">
#   <caption>H₀: Потребление алкоголя в будни и наличие провалов — независимы | H₁: Студенты с высоким Dalc имеют значимо больше академических провалов</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12dfe_level0_col0" class="col_heading level0 col0" >Значение</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Параметр</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12dfe_level0_row0" class="row_heading level0 row0" >Тест</th>
#       <td id="T_12dfe_row0_col0" class="data row0 col0" >χ² Пирсона</td>
#     </tr>
#     <tr>
#       <th id="T_12dfe_level0_row1" class="row_heading level0 row1" >χ²-статистика</th>
#       <td id="T_12dfe_row1_col0" class="data row1 col0" >13.196100</td>
#     </tr>
#     <tr>
#       <th id="T_12dfe_level0_row2" class="row_heading level0 row2" >Степени свободы (df)</th>
#       <td id="T_12dfe_row2_col0" class="data row2 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_12dfe_level0_row3" class="row_heading level0 row3" >Мин. ожидаемая частота</th>
#       <td id="T_12dfe_row3_col0" class="data row3 col0" >25.010000</td>
#     </tr>
#     <tr>
#       <th id="T_12dfe_level0_row4" class="row_heading level0 row4" >p-value</th>
#       <td id="T_12dfe_row4_col0" class="data row4 col0" >0.000281</td>
#     </tr>
#     <tr>
#       <th id="T_12dfe_level0_row5" class="row_heading level0 row5" >Уровень значимости α</th>
#       <td id="T_12dfe_row5_col0" class="data row5 col0" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_12dfe_level0_row6" class="row_heading level0 row6" >Вывод</th>
#       <td id="T_12dfe_row6_col0" class="data row6 col0" >✅ Отвергаем H₀ — переменные зависимы</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **H₀:** Уровень потребления алкоголя в будни (Dalc) и наличие
# академических провалов — независимы.
# **H₁:** Студенты с высоким Dalc имеют значимо больше провалов.
#
# **Интерпретация:**
# Среди студентов с высоким Dalc (≥2) доля имеющих хотя бы один провал
# составляет **~33%**, тогда как при Dalc=1 — лишь **~16%**.
# **χ² p = 0.0003** → ✅ отвергаем H₀.
# Потребление алкоголя в рабочие дни статистически значимо связано
# с академическими провалами — это наиболее прямое свидетельство
# негативного влияния алкоголя на учёбу в данном датасете.

# %%
# -------------------------------------------------------------
# 5.3 goout_bin × Walc_bin: социальная активность и алкоголь
# -------------------------------------------------------------

ct_53, pct_53, res_53, raw_53, rawpct_53, p_53 = run_chi2_full(
    "goout_bin", "Walc_bin", "goout", "Walc",
    h0="Частота выходов с друзьями и уровень Walc — независимы",
    h1="Студенты, часто выходящие с друзьями, пьют значимо больше",
    caption="Таблица 13 — goout_bin × Walc_bin"
)
display(ct_53)
display(pct_53)
display(res_53)
# Out:
# <style type="text/css">
# #T_daa4f caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_daa4f th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_daa4f td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_daa4f tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_daa4f_row0_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_daa4f_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_daa4f_row1_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_daa4f_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_daa4f">
#   <caption>Таблица 13 — goout_bin × Walc_bin</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Walc_bin</th>
#       <th id="T_daa4f_level0_col0" class="col_heading level0 col0" >Высокий (≥3)</th>
#       <th id="T_daa4f_level0_col1" class="col_heading level0 col1" >Низкий (≤2)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >goout_bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_daa4f_level0_row0" class="row_heading level0 row0" >Редко (≤3)</th>
#       <td id="T_daa4f_row0_col0" class="data row0 col0" >70</td>
#       <td id="T_daa4f_row0_col1" class="data row0 col1" >186</td>
#     </tr>
#     <tr>
#       <th id="T_daa4f_level0_row1" class="row_heading level0 row1" >Часто (≥4)</th>
#       <td id="T_daa4f_row1_col0" class="data row1 col0" >89</td>
#       <td id="T_daa4f_row1_col1" class="data row1 col1" >50</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_69f2a caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_69f2a th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_69f2a td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_69f2a tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_69f2a_row0_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_69f2a_row0_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_69f2a_row1_col0 {
#   background-color: #d00d21;
#   color: #f1f1f1;
# }
# #T_69f2a_row1_col1 {
#   background-color: #fee38b;
#   color: #000000;
# }
# </style>
# <table id="T_69f2a">
#   <caption>Доли по строкам (%) — goout × Walc</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Walc_bin</th>
#       <th id="T_69f2a_level0_col0" class="col_heading level0 col0" >Высокий (≥3)</th>
#       <th id="T_69f2a_level0_col1" class="col_heading level0 col1" >Низкий (≤2)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >goout_bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69f2a_level0_row0" class="row_heading level0 row0" >Редко (≤3)</th>
#       <td id="T_69f2a_row0_col0" class="data row0 col0" >27.3%</td>
#       <td id="T_69f2a_row0_col1" class="data row0 col1" >72.7%</td>
#     </tr>
#     <tr>
#       <th id="T_69f2a_level0_row1" class="row_heading level0 row1" >Часто (≥4)</th>
#       <td id="T_69f2a_row1_col0" class="data row1 col0" >64.0%</td>
#       <td id="T_69f2a_row1_col1" class="data row1 col1" >36.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_aa246 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_aa246 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_aa246 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_aa246 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_aa246_row4_col0, #T_aa246_row6_col0 {
#   background-color: #d5f5e3;
# }
# </style>
# <table id="T_aa246">
#   <caption>H₀: Частота выходов с друзьями и уровень Walc — независимы | H₁: Студенты, часто выходящие с друзьями, пьют значимо больше</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa246_level0_col0" class="col_heading level0 col0" >Значение</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Параметр</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa246_level0_row0" class="row_heading level0 row0" >Тест</th>
#       <td id="T_aa246_row0_col0" class="data row0 col0" >χ² Пирсона</td>
#     </tr>
#     <tr>
#       <th id="T_aa246_level0_row1" class="row_heading level0 row1" >χ²-статистика</th>
#       <td id="T_aa246_row1_col0" class="data row1 col0" >48.896600</td>
#     </tr>
#     <tr>
#       <th id="T_aa246_level0_row2" class="row_heading level0 row2" >Степени свободы (df)</th>
#       <td id="T_aa246_row2_col0" class="data row2 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_aa246_level0_row3" class="row_heading level0 row3" >Мин. ожидаемая частота</th>
#       <td id="T_aa246_row3_col0" class="data row3 col0" >55.950000</td>
#     </tr>
#     <tr>
#       <th id="T_aa246_level0_row4" class="row_heading level0 row4" >p-value</th>
#       <td id="T_aa246_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aa246_level0_row5" class="row_heading level0 row5" >Уровень значимости α</th>
#       <td id="T_aa246_row5_col0" class="data row5 col0" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_aa246_level0_row6" class="row_heading level0 row6" >Вывод</th>
#       <td id="T_aa246_row6_col0" class="data row6 col0" >✅ Отвергаем H₀ — переменные зависимы</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **H₀:** Частота выходов с друзьями (goout) и уровень потребления
# алкоголя в выходные (Walc) — независимы.
# **H₁:** Студенты, часто выходящие с друзьями, имеют значимо более
# высокий уровень Walc.
#
# **Интерпретация:**
# Среди часто выходящих студентов (goout ≥ 4) **~64%** имеют высокий Walc,
# тогда как среди редко выходящих — лишь **~27%**.
# **χ² p < 0.000001** → ✅ отвергаем H₀ с очень высокой значимостью.
# Это самая сильная связь среди всех протестированных — социальная
# активность является ключевым предиктором алкогольного поведения.

# %% [markdown]
# ## VI. Анализ дисперсии — ANOVA
#
# ### Что такое ANOVA?
# ANOVA (Analysis of Variance) — тест для сравнения средних **трёх и более
# групп** одновременно без увеличения ошибки I рода.
#
# **F-статистика = Межгрупповая дисперсия / Внутригрупповая дисперсия**
# Чем больше F → тем сильнее группы отличаются → тем меньше p-value.
#
# **Условия применения:**
# 1. Нормальность в каждой группе (тест Шапиро-Уилка)
# 2. Однородность дисперсий (тест Левена)
# 3. Независимость наблюдений
#
# **Если условия нарушены → Kruskal-Wallis:**
# Непараметрический аналог ANOVA — не требует нормальности.
# Работает с рангами вместо исходных значений.
# Мы применяем оба теста и сравниваем выводы.
#
# **Если ANOVA/KW значима → пост-хок Бонферрони:**
# Попарные сравнения с поправкой на множественность тестов.

# %%
# =============================================================
# VI. Анализ дисперсии — ANOVA + Kruskal-Wallis
# =============================================================

from scipy.stats import f_oneway, shapiro, levene, kruskal
from scipy.stats import ttest_ind
from itertools import combinations
# -------------------------------------------------------------
# Вспомогательные функции
# -------------------------------------------------------------

def run_anova_full(data, group_col, value_col, caption):
    """
    ANOVA + Kruskal-Wallis + проверка условий.
    """
    group_labels = sorted(data[group_col].unique())
    groups = [data[data[group_col] == g][value_col].values
              for g in group_labels]

    # Шапиро-Уилк
    shapiro_rows = []
    for label, grp in zip(group_labels, groups):
        if len(grp) >= 3:
            stat, p = shapiro(grp[:50])
            shapiro_rows.append({
                "Группа":       label,
                "n":            len(grp),
                "Среднее":      round(grp.mean(), 3),
                "W-статистика": round(stat, 4),
                "p-value":      round(p, 4),
                "Нормальность": "✅ Да" if p > 0.05 else "⚠️ Нет"
            })
    shapiro_df = pd.DataFrame(shapiro_rows).set_index("Группа")

    # Левен
    lev_stat, lev_p = levene(*groups)

    # ANOVA
    f_stat, p_anova = f_oneway(*groups)

    # Kruskal-Wallis
    h_stat, p_kw = kruskal(*groups)

    # Нормальность нарушена если хотя бы в одной группе
    normality_ok = all(shapiro_rows[i]["p-value"] > 0.05
                       for i in range(len(shapiro_rows)))

    anova_result = pd.DataFrame({
        "Параметр": [
            "Количество групп", "Общее n",
            "─── Проверка условий ───",
            "Тест Левена (p-value)", "Однородность дисперсий",
            "Нормальность (Шапиро)", 
            "─── ANOVA (параметрический) ───",
            "F-статистика", "p-value ANOVA",
            "─── Kruskal-Wallis (непараметрический) ───",
            "H-статистика", "p-value Kruskal-Wallis",
            "─── Вывод ───",
            "Рекомендуемый тест",
            "Итоговый вывод"
        ],
        "Значение": [
            len(groups), sum(len(g) for g in groups),
            "──────────────────",
            round(lev_p, 4),
            "✅ Однородны" if lev_p > 0.05 else "⚠️ Неоднородны",
            "✅ Норм. во всех" if normality_ok else "⚠️ Нарушена",
            "──────────────────",
            round(f_stat, 4), round(p_anova, 6),
            "──────────────────",
            round(h_stat, 4), round(p_kw, 6),
            "──────────────────",
            "ANOVA" if normality_ok and lev_p > 0.05
                    else "Kruskal-Wallis (условия нарушены)",
            ("✅ Отвергаем H₀" if p_kw < 0.05
             else "❌ Не отвергаем H₀")
        ]
    }).set_index("Параметр")

    styled_shapiro = shapiro_df.style \
        .apply(lambda col: [
            "background-color: #d5f5e3" if v == "✅ Да"
            else "background-color: #fde8d8"
            for v in col], subset=["Нормальность"]) \
        .background_gradient(cmap="RdYlGn",
                             subset=["Среднее"], axis=0) \
        .format({"n": "{:.0f}", "Среднее": "{:.3f}",
                 "W-статистика": "{:.4f}", "p-value": "{:.4f}"}) \
        .set_caption(
            f"Тест Шапиро-Уилка — нормальность групп ({group_col})") \
        .set_table_styles(TABLE_HEADER_STYLE)

    styled_anova = anova_result.style \
        .highlight_between(
            subset=pd.IndexSlice[["Итоговый вывод"], :],
            color="#d5f5e3" if p_kw < 0.05 else "#fde8d8") \
        .highlight_between(
            subset=pd.IndexSlice[["p-value ANOVA",
                                   "p-value Kruskal-Wallis"], :],
            color="#d5f5e3" if p_kw < 0.05 else "#fde8d8") \
        .set_caption(caption) \
        .set_table_styles(TABLE_HEADER_STYLE)

    return (styled_shapiro, styled_anova,
            f_stat, p_anova, h_stat, p_kw,
            group_labels, groups, shapiro_df)


def run_posthoc_bonferroni(data, group_col, value_col):
    """
    Пост-хок: попарные t-тесты Уэлча + поправка Бонферрони.
    Исправленная версия без NaN в колонках.
    """
    group_labels = sorted(data[group_col].unique())
    groups_dict  = {g: data[data[group_col] == g][value_col].values
                    for g in group_labels}
    pairs   = list(combinations(group_labels, 2))
    n_pairs = len(pairs)

    rows = []
    for g1, g2 in pairs:
        t_stat, p_raw = ttest_ind(
            groups_dict[g1], groups_dict[g2], equal_var=False)
        p_bonf = min(p_raw * n_pairs, 1.0)
        rows.append({
            "Группа 1":            str(g1),
            "Группа 2":            str(g2),
            "Среднее (гр. 1)":     round(groups_dict[g1].mean(), 3),
            "Среднее (гр. 2)":     round(groups_dict[g2].mean(), 3),
            "Разница средних":     round(
                groups_dict[g1].mean() - groups_dict[g2].mean(), 3),
            "p-value (сырой)":     round(p_raw, 5),
            "p-value (Бонферрони)":round(p_bonf, 5),
            "Значимо?":            "✅ Да" if p_bonf < 0.05 else "❌ Нет"
        })

    df_out = pd.DataFrame(rows)

    styled = df_out.style \
        .apply(lambda col: [
            "background-color: #d5f5e3" if v == "✅ Да"
            else "background-color: #fde8d8"
            for v in col], subset=["Значимо?"]) \
        .background_gradient(
            cmap="RdYlGn_r",
            subset=["p-value (Бонферрони)"], axis=0) \
        .format({
            "Среднее (гр. 1)": "{:.3f}",
            "Среднее (гр. 2)": "{:.3f}",
            "Разница средних": "{:.3f}",
            "p-value (сырой)": "{:.5f}",
            "p-value (Бонферрони)": "{:.5f}"
        }) \
        .set_caption(
            "Пост-хок анализ — попарные t-тесты + поправка Бонферрони") \
        .set_table_styles(TABLE_HEADER_STYLE)

    return styled, df_out

# %%
# -------------------------------------------------------------
# 6.1 G3 по уровням Walc (5 групп)
# -------------------------------------------------------------

sh_61, an_61, f_61, p_61, h_61, pkw_61, \
    lbl_61, grp_61, sdf_61 = run_anova_full(
        df, "Walc", "G3",
        "Таблица 14 — ANOVA + Kruskal-Wallis: G3 по уровням Walc"
    )
display(sh_61)
display(an_61)
# Out:
# <style type="text/css">
# #T_8edf0 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_8edf0 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_8edf0 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_8edf0 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_8edf0_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8edf0_row0_col4, #T_8edf0_row1_col4, #T_8edf0_row3_col4 {
#   background-color: #fde8d8;
# }
# #T_8edf0_row1_col1 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_8edf0_row2_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_8edf0_row2_col4, #T_8edf0_row4_col4 {
#   background-color: #d5f5e3;
# }
# #T_8edf0_row3_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8edf0_row4_col1 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# </style>
# <table id="T_8edf0">
#   <caption>Тест Шапиро-Уилка — нормальность групп (Walc)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8edf0_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_8edf0_level0_col1" class="col_heading level0 col1" >Среднее</th>
#       <th id="T_8edf0_level0_col2" class="col_heading level0 col2" >W-статистика</th>
#       <th id="T_8edf0_level0_col3" class="col_heading level0 col3" >p-value</th>
#       <th id="T_8edf0_level0_col4" class="col_heading level0 col4" >Нормальность</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Группа</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8edf0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8edf0_row0_col0" class="data row0 col0" >151</td>
#       <td id="T_8edf0_row0_col1" class="data row0 col1" >10.735</td>
#       <td id="T_8edf0_row0_col2" class="data row0 col2" >0.9452</td>
#       <td id="T_8edf0_row0_col3" class="data row0 col3" >0.0217</td>
#       <td id="T_8edf0_row0_col4" class="data row0 col4" >⚠️ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_8edf0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8edf0_row1_col0" class="data row1 col0" >85</td>
#       <td id="T_8edf0_row1_col1" class="data row1 col1" >10.082</td>
#       <td id="T_8edf0_row1_col2" class="data row1 col2" >0.8699</td>
#       <td id="T_8edf0_row1_col3" class="data row1 col3" >0.0001</td>
#       <td id="T_8edf0_row1_col4" class="data row1 col4" >⚠️ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_8edf0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_8edf0_row2_col0" class="data row2 col0" >80</td>
#       <td id="T_8edf0_row2_col1" class="data row2 col1" >10.725</td>
#       <td id="T_8edf0_row2_col2" class="data row2 col2" >0.9585</td>
#       <td id="T_8edf0_row2_col3" class="data row2 col3" >0.0772</td>
#       <td id="T_8edf0_row2_col4" class="data row2 col4" >✅ Да</td>
#     </tr>
#     <tr>
#       <th id="T_8edf0_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_8edf0_row3_col0" class="data row3 col0" >51</td>
#       <td id="T_8edf0_row3_col1" class="data row3 col1" >9.686</td>
#       <td id="T_8edf0_row3_col2" class="data row3 col2" >0.9290</td>
#       <td id="T_8edf0_row3_col3" class="data row3 col3" >0.0051</td>
#       <td id="T_8edf0_row3_col4" class="data row3 col4" >⚠️ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_8edf0_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_8edf0_row4_col0" class="data row4 col0" >28</td>
#       <td id="T_8edf0_row4_col1" class="data row4 col1" >10.143</td>
#       <td id="T_8edf0_row4_col2" class="data row4 col2" >0.9379</td>
#       <td id="T_8edf0_row4_col3" class="data row4 col3" >0.0976</td>
#       <td id="T_8edf0_row4_col4" class="data row4 col4" >✅ Да</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ade7d caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_ade7d th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_ade7d td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_ade7d tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_ade7d_row8_col0, #T_ade7d_row11_col0, #T_ade7d_row14_col0 {
#   background-color: #fde8d8;
# }
# </style>
# <table id="T_ade7d">
#   <caption>Таблица 14 — ANOVA + Kruskal-Wallis: G3 по уровням Walc</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ade7d_level0_col0" class="col_heading level0 col0" >Значение</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Параметр</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ade7d_level0_row0" class="row_heading level0 row0" >Количество групп</th>
#       <td id="T_ade7d_row0_col0" class="data row0 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row1" class="row_heading level0 row1" >Общее n</th>
#       <td id="T_ade7d_row1_col0" class="data row1 col0" >395</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row2" class="row_heading level0 row2" >─── Проверка условий ───</th>
#       <td id="T_ade7d_row2_col0" class="data row2 col0" >──────────────────</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row3" class="row_heading level0 row3" >Тест Левена (p-value)</th>
#       <td id="T_ade7d_row3_col0" class="data row3 col0" >0.015100</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row4" class="row_heading level0 row4" >Однородность дисперсий</th>
#       <td id="T_ade7d_row4_col0" class="data row4 col0" >⚠️ Неоднородны</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row5" class="row_heading level0 row5" >Нормальность (Шапиро)</th>
#       <td id="T_ade7d_row5_col0" class="data row5 col0" >⚠️ Нарушена</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row6" class="row_heading level0 row6" >─── ANOVA (параметрический) ───</th>
#       <td id="T_ade7d_row6_col0" class="data row6 col0" >──────────────────</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row7" class="row_heading level0 row7" >F-статистика</th>
#       <td id="T_ade7d_row7_col0" class="data row7 col0" >0.733200</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row8" class="row_heading level0 row8" >p-value ANOVA</th>
#       <td id="T_ade7d_row8_col0" class="data row8 col0" >0.569750</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row9" class="row_heading level0 row9" >─── Kruskal-Wallis (непараметрический) ───</th>
#       <td id="T_ade7d_row9_col0" class="data row9 col0" >──────────────────</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row10" class="row_heading level0 row10" >H-статистика</th>
#       <td id="T_ade7d_row10_col0" class="data row10 col0" >5.453000</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row11" class="row_heading level0 row11" >p-value Kruskal-Wallis</th>
#       <td id="T_ade7d_row11_col0" class="data row11 col0" >0.243894</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row12" class="row_heading level0 row12" >─── Вывод ───</th>
#       <td id="T_ade7d_row12_col0" class="data row12 col0" >──────────────────</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row13" class="row_heading level0 row13" >Рекомендуемый тест</th>
#       <td id="T_ade7d_row13_col0" class="data row13 col0" >Kruskal-Wallis (условия нарушены)</td>
#     </tr>
#     <tr>
#       <th id="T_ade7d_level0_row14" class="row_heading level0 row14" >Итоговый вывод</th>
#       <td id="T_ade7d_row14_col0" class="data row14 col0" >❌ Не отвергаем H₀</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **H₀:** Средняя итоговая оценка G3 одинакова во всех 5 группах Walc.
# **H₁:** Хотя бы одна группа имеет значимо отличающееся среднее G3.
#
# **Обоснование ANOVA:**
# Walc принимает 5 значений → сравнение более двух групп → t-тест
# неприменим. ANOVA проверяет все группы одновременно.
#
# **Почему дополнительно Kruskal-Wallis:**
# Тест Шапиро-Уилка выявил нарушение нормальности в 3 из 5 групп,
# а тест Левена показал неоднородность дисперсий.
# В таких условиях Kruskal-Wallis более надёжен.
# Если оба теста дают одинаковый вывод — результат устойчив.
#
# **Интерпретация:**
# ANOVA: F = 0.733, p = 0.570 → не отвергаем H₀.
# Kruskal-Wallis: H = 5.453, p = 0.244 → не отвергаем H₀.
# Оба теста согласуются: при разбивке по всем 5 уровням Walc
# значимых различий в G3 нет. Это объясняется высокой вариабельностью
# оценок внутри каждой группы и малым числом студентов в группах 4–5.
# Визуальный тренд снижения G3 существует, но не достигает
# статистической значимости при данном размере выборки.

# %%
# -------------------------------------------------------------
# 6.1 Визуализация: G3 по Walc
# -------------------------------------------------------------

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
palette_w = ["#2ecc71","#3498db","#f39c12","#e67e22","#e74c3c"]

# Boxplot с hue (без FutureWarning)
df["Walc_str"] = df["Walc"].astype(str)
sns.boxplot(data=df, x="Walc", y="G3",
            hue="Walc", palette=palette_w,
            width=0.5, linewidth=1.5,
            flierprops=dict(marker="o", alpha=0.4),
            legend=False, ax=axes[0])
axes[0].set_title(
    f"G3 по уровням Walc\n"
    f"ANOVA: F={f_61:.3f}, p={p_61:.3f} | "
    f"KW: H={h_61:.3f}, p={pkw_61:.3f}",
    fontsize=11, fontweight="bold")
axes[0].set_xlabel("Walc (1=очень низкий, 5=очень высокий)")
axes[0].set_ylabel("Итоговая оценка G3")

# График средних с ДИ
means_w = df.groupby("Walc")["G3"].mean()
sems_w  = df.groupby("Walc")["G3"].sem()

axes[1].errorbar(means_w.index, means_w.values,
                 yerr=1.96*sems_w.values,
                 fmt="o-", color="#2c3e50",
                 markersize=10, linewidth=2.5,
                 capsize=8, capthick=2,
                 label="Среднее ± 95% ДИ")
for level, (mean_val, sem_val) in enumerate(
        zip(means_w.values, sems_w.values), start=1):
    axes[1].annotate(
        f"{mean_val:.2f}",
        (level, mean_val),
        textcoords="offset points",
        xytext=(0, 12), ha="center",
        fontsize=10, fontweight="bold",
        color=palette_w[level-1])

axes[1].set_title("Средние G3 ± 95% ДИ по уровням Walc",
                  fontsize=12, fontweight="bold")
axes[1].set_xlabel("Walc")
axes[1].set_ylabel("Средняя G3")
axes[1].set_xticks(sorted(df["Walc"].unique()))
axes[1].legend()

plt.tight_layout()
plt.savefig("anova_G3_Walc.png", bbox_inches="tight")
plt.show()

# %%
# -------------------------------------------------------------
# 6.2 ANOVA: Walc по уровням goout (5 групп)
# -------------------------------------------------------------

sh_62, an_62, f_62, p_62, h_62, pkw_62, \
    lbl_62, grp_62, sdf_62 = run_anova_full(
        df, "goout", "Walc",
        "Таблица 15 — ANOVA + Kruskal-Wallis: Walc по уровням goout"
    )
display(sh_62)
display(an_62)
# Out:
# <style type="text/css">
# #T_9ab40 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_9ab40 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_9ab40 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_9ab40 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_9ab40_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_9ab40_row0_col4, #T_9ab40_row1_col4, #T_9ab40_row2_col4, #T_9ab40_row3_col4, #T_9ab40_row4_col4 {
#   background-color: #fde8d8;
# }
# #T_9ab40_row1_col1 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_9ab40_row2_col1 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_9ab40_row3_col1 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_9ab40_row4_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9ab40">
#   <caption>Тест Шапиро-Уилка — нормальность групп (goout)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ab40_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_9ab40_level0_col1" class="col_heading level0 col1" >Среднее</th>
#       <th id="T_9ab40_level0_col2" class="col_heading level0 col2" >W-статистика</th>
#       <th id="T_9ab40_level0_col3" class="col_heading level0 col3" >p-value</th>
#       <th id="T_9ab40_level0_col4" class="col_heading level0 col4" >Нормальность</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Группа</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ab40_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9ab40_row0_col0" class="data row0 col0" >23</td>
#       <td id="T_9ab40_row0_col1" class="data row0 col1" >1.609</td>
#       <td id="T_9ab40_row0_col2" class="data row0 col2" >0.6664</td>
#       <td id="T_9ab40_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_9ab40_row0_col4" class="data row0 col4" >⚠️ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_9ab40_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9ab40_row1_col0" class="data row1 col0" >103</td>
#       <td id="T_9ab40_row1_col1" class="data row1 col1" >1.767</td>
#       <td id="T_9ab40_row1_col2" class="data row1 col2" >0.6692</td>
#       <td id="T_9ab40_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_9ab40_row1_col4" class="data row1 col4" >⚠️ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_9ab40_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9ab40_row2_col0" class="data row2 col0" >130</td>
#       <td id="T_9ab40_row2_col1" class="data row2 col1" >2.108</td>
#       <td id="T_9ab40_row2_col2" class="data row2 col2" >0.8230</td>
#       <td id="T_9ab40_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_9ab40_row2_col4" class="data row2 col4" >⚠️ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_9ab40_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9ab40_row3_col0" class="data row3 col0" >86</td>
#       <td id="T_9ab40_row3_col1" class="data row3 col1" >2.698</td>
#       <td id="T_9ab40_row3_col2" class="data row3 col2" >0.8654</td>
#       <td id="T_9ab40_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_9ab40_row3_col4" class="data row3 col4" >⚠️ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_9ab40_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_9ab40_row4_col0" class="data row4 col0" >53</td>
#       <td id="T_9ab40_row4_col1" class="data row4 col1" >3.396</td>
#       <td id="T_9ab40_row4_col2" class="data row4 col2" >0.8438</td>
#       <td id="T_9ab40_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_9ab40_row4_col4" class="data row4 col4" >⚠️ Нет</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_23fb5 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_23fb5 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_23fb5 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_23fb5 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_23fb5_row8_col0, #T_23fb5_row11_col0, #T_23fb5_row14_col0 {
#   background-color: #d5f5e3;
# }
# </style>
# <table id="T_23fb5">
#   <caption>Таблица 15 — ANOVA + Kruskal-Wallis: Walc по уровням goout</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23fb5_level0_col0" class="col_heading level0 col0" >Значение</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Параметр</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23fb5_level0_row0" class="row_heading level0 row0" >Количество групп</th>
#       <td id="T_23fb5_row0_col0" class="data row0 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row1" class="row_heading level0 row1" >Общее n</th>
#       <td id="T_23fb5_row1_col0" class="data row1 col0" >395</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row2" class="row_heading level0 row2" >─── Проверка условий ───</th>
#       <td id="T_23fb5_row2_col0" class="data row2 col0" >──────────────────</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row3" class="row_heading level0 row3" >Тест Левена (p-value)</th>
#       <td id="T_23fb5_row3_col0" class="data row3 col0" >0.001300</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row4" class="row_heading level0 row4" >Однородность дисперсий</th>
#       <td id="T_23fb5_row4_col0" class="data row4 col0" >⚠️ Неоднородны</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row5" class="row_heading level0 row5" >Нормальность (Шапиро)</th>
#       <td id="T_23fb5_row5_col0" class="data row5 col0" >⚠️ Нарушена</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row6" class="row_heading level0 row6" >─── ANOVA (параметрический) ───</th>
#       <td id="T_23fb5_row6_col0" class="data row6 col0" >──────────────────</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row7" class="row_heading level0 row7" >F-статистика</th>
#       <td id="T_23fb5_row7_col0" class="data row7 col0" >22.451900</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row8" class="row_heading level0 row8" >p-value ANOVA</th>
#       <td id="T_23fb5_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row9" class="row_heading level0 row9" >─── Kruskal-Wallis (непараметрический) ───</th>
#       <td id="T_23fb5_row9_col0" class="data row9 col0" >──────────────────</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row10" class="row_heading level0 row10" >H-статистика</th>
#       <td id="T_23fb5_row10_col0" class="data row10 col0" >63.440900</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row11" class="row_heading level0 row11" >p-value Kruskal-Wallis</th>
#       <td id="T_23fb5_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row12" class="row_heading level0 row12" >─── Вывод ───</th>
#       <td id="T_23fb5_row12_col0" class="data row12 col0" >──────────────────</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row13" class="row_heading level0 row13" >Рекомендуемый тест</th>
#       <td id="T_23fb5_row13_col0" class="data row13 col0" >Kruskal-Wallis (условия нарушены)</td>
#     </tr>
#     <tr>
#       <th id="T_23fb5_level0_row14" class="row_heading level0 row14" >Итоговый вывод</th>
#       <td id="T_23fb5_row14_col0" class="data row14 col0" >✅ Отвергаем H₀</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **H₀:** Среднее потребление алкоголя в выходные (Walc) одинаково
# во всех 5 группах частоты выходов с друзьями (goout).
# **H₁:** Хотя бы одна группа имеет значимо отличающийся средний Walc.
#
# **Обоснование:**
# goout имеет 5 уровней → ANOVA вместо t-теста. Spearman-корреляция
# (раздел 2.5): goout × Walc ρ = +0.393, p < 0.001 — самая сильная
# связь во всём датасете. ANOVA формально проверяет: существуют ли
# значимые различия в Walc между группами с разной социальной активностью.
#
# **Связь с темой:**
# χ²-тест (5.3) показал бинарную связь goout_bin × Walc_bin.
# ANOVA здесь более детальна: видим, на каком именно уровне goout
# начинается значимый рост потребления алкоголя.

# %%
# -------------------------------------------------------------
# 6.2 Пост-хок для Walc ~ goout
# -------------------------------------------------------------

if pkw_62 < 0.05:
    tk_62, tk_62_raw = run_posthoc_bonferroni(df, "goout", "Walc")
    display(tk_62)
else:
    display(Markdown(
        "**Пост-хок не проводится** — результат незначим."))
# Out:
# <style type="text/css">
# #T_25f86 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_25f86 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_25f86 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_25f86 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_25f86_row0_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_25f86_row0_col7, #T_25f86_row1_col7, #T_25f86_row4_col7, #T_25f86_row9_col7 {
#   background-color: #fde8d8;
# }
# #T_25f86_row1_col6 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_25f86_row2_col6, #T_25f86_row3_col6, #T_25f86_row5_col6, #T_25f86_row6_col6, #T_25f86_row8_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_25f86_row2_col7, #T_25f86_row3_col7, #T_25f86_row5_col7, #T_25f86_row6_col7, #T_25f86_row7_col7, #T_25f86_row8_col7 {
#   background-color: #d5f5e3;
# }
# #T_25f86_row4_col6 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_25f86_row7_col6 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_25f86_row9_col6 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_25f86">
#   <caption>Пост-хок анализ — попарные t-тесты + поправка Бонферрони</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25f86_level0_col0" class="col_heading level0 col0" >Группа 1</th>
#       <th id="T_25f86_level0_col1" class="col_heading level0 col1" >Группа 2</th>
#       <th id="T_25f86_level0_col2" class="col_heading level0 col2" >Среднее (гр. 1)</th>
#       <th id="T_25f86_level0_col3" class="col_heading level0 col3" >Среднее (гр. 2)</th>
#       <th id="T_25f86_level0_col4" class="col_heading level0 col4" >Разница средних</th>
#       <th id="T_25f86_level0_col5" class="col_heading level0 col5" >p-value (сырой)</th>
#       <th id="T_25f86_level0_col6" class="col_heading level0 col6" >p-value (Бонферрони)</th>
#       <th id="T_25f86_level0_col7" class="col_heading level0 col7" >Значимо?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25f86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25f86_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_25f86_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_25f86_row0_col2" class="data row0 col2" >1.609</td>
#       <td id="T_25f86_row0_col3" class="data row0 col3" >1.767</td>
#       <td id="T_25f86_row0_col4" class="data row0 col4" >-0.158</td>
#       <td id="T_25f86_row0_col5" class="data row0 col5" >0.49325</td>
#       <td id="T_25f86_row0_col6" class="data row0 col6" >1.00000</td>
#       <td id="T_25f86_row0_col7" class="data row0 col7" >❌ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_25f86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_25f86_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_25f86_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_25f86_row1_col2" class="data row1 col2" >1.609</td>
#       <td id="T_25f86_row1_col3" class="data row1 col3" >2.108</td>
#       <td id="T_25f86_row1_col4" class="data row1 col4" >-0.499</td>
#       <td id="T_25f86_row1_col5" class="data row1 col5" >0.03460</td>
#       <td id="T_25f86_row1_col6" class="data row1 col6" >0.34604</td>
#       <td id="T_25f86_row1_col7" class="data row1 col7" >❌ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_25f86_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_25f86_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_25f86_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_25f86_row2_col2" class="data row2 col2" >1.609</td>
#       <td id="T_25f86_row2_col3" class="data row2 col3" >2.698</td>
#       <td id="T_25f86_row2_col4" class="data row2 col4" >-1.089</td>
#       <td id="T_25f86_row2_col5" class="data row2 col5" >0.00008</td>
#       <td id="T_25f86_row2_col6" class="data row2 col6" >0.00080</td>
#       <td id="T_25f86_row2_col7" class="data row2 col7" >✅ Да</td>
#     </tr>
#     <tr>
#       <th id="T_25f86_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_25f86_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_25f86_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_25f86_row3_col2" class="data row3 col2" >1.609</td>
#       <td id="T_25f86_row3_col3" class="data row3 col3" >3.396</td>
#       <td id="T_25f86_row3_col4" class="data row3 col4" >-1.788</td>
#       <td id="T_25f86_row3_col5" class="data row3 col5" >0.00000</td>
#       <td id="T_25f86_row3_col6" class="data row3 col6" >0.00000</td>
#       <td id="T_25f86_row3_col7" class="data row3 col7" >✅ Да</td>
#     </tr>
#     <tr>
#       <th id="T_25f86_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_25f86_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_25f86_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_25f86_row4_col2" class="data row4 col2" >1.767</td>
#       <td id="T_25f86_row4_col3" class="data row4 col3" >2.108</td>
#       <td id="T_25f86_row4_col4" class="data row4 col4" >-0.341</td>
#       <td id="T_25f86_row4_col5" class="data row4 col5" >0.01263</td>
#       <td id="T_25f86_row4_col6" class="data row4 col6" >0.12635</td>
#       <td id="T_25f86_row4_col7" class="data row4 col7" >❌ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_25f86_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_25f86_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_25f86_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_25f86_row5_col2" class="data row5 col2" >1.767</td>
#       <td id="T_25f86_row5_col3" class="data row5 col3" >2.698</td>
#       <td id="T_25f86_row5_col4" class="data row5 col4" >-0.931</td>
#       <td id="T_25f86_row5_col5" class="data row5 col5" >0.00000</td>
#       <td id="T_25f86_row5_col6" class="data row5 col6" >0.00000</td>
#       <td id="T_25f86_row5_col7" class="data row5 col7" >✅ Да</td>
#     </tr>
#     <tr>
#       <th id="T_25f86_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_25f86_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_25f86_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_25f86_row6_col2" class="data row6 col2" >1.767</td>
#       <td id="T_25f86_row6_col3" class="data row6 col3" >3.396</td>
#       <td id="T_25f86_row6_col4" class="data row6 col4" >-1.629</td>
#       <td id="T_25f86_row6_col5" class="data row6 col5" >0.00000</td>
#       <td id="T_25f86_row6_col6" class="data row6 col6" >0.00000</td>
#       <td id="T_25f86_row6_col7" class="data row6 col7" >✅ Да</td>
#     </tr>
#     <tr>
#       <th id="T_25f86_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_25f86_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_25f86_row7_col1" class="data row7 col1" >4</td>
#       <td id="T_25f86_row7_col2" class="data row7 col2" >2.108</td>
#       <td id="T_25f86_row7_col3" class="data row7 col3" >2.698</td>
#       <td id="T_25f86_row7_col4" class="data row7 col4" >-0.590</td>
#       <td id="T_25f86_row7_col5" class="data row7 col5" >0.00075</td>
#       <td id="T_25f86_row7_col6" class="data row7 col6" >0.00752</td>
#       <td id="T_25f86_row7_col7" class="data row7 col7" >✅ Да</td>
#     </tr>
#     <tr>
#       <th id="T_25f86_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_25f86_row8_col0" class="data row8 col0" >3</td>
#       <td id="T_25f86_row8_col1" class="data row8 col1" >5</td>
#       <td id="T_25f86_row8_col2" class="data row8 col2" >2.108</td>
#       <td id="T_25f86_row8_col3" class="data row8 col3" >3.396</td>
#       <td id="T_25f86_row8_col4" class="data row8 col4" >-1.289</td>
#       <td id="T_25f86_row8_col5" class="data row8 col5" >0.00000</td>
#       <td id="T_25f86_row8_col6" class="data row8 col6" >0.00000</td>
#       <td id="T_25f86_row8_col7" class="data row8 col7" >✅ Да</td>
#     </tr>
#     <tr>
#       <th id="T_25f86_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_25f86_row9_col0" class="data row9 col0" >4</td>
#       <td id="T_25f86_row9_col1" class="data row9 col1" >5</td>
#       <t

# %% [markdown]
# **Интерпретация пост-хок анализа:**
# Поправка Бонферрони применяется к 10 попарным сравнениям (5 групп).
# Строки ✅ указывают пары, где разница в Walc статистически значима.
# Ожидаем значимые различия между крайними группами
# (goout=1 vs goout=4–5) — студенты, часто выходящие с друзьями,
# потребляют алкоголь значимо больше, чем почти не выходящие.

# %%
# -------------------------------------------------------------
# 6.2 Визуализация: Walc по уровням goout
# -------------------------------------------------------------

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
palette_g = ["#2ecc71","#3498db","#f39c12","#e67e22","#e74c3c"]

# Boxplot
sns.boxplot(data=df, x="goout", y="Walc",
            hue="goout", palette=palette_g,
            width=0.5, linewidth=1.5,
            flierprops=dict(marker="o", alpha=0.4),
            legend=False, ax=axes[0])
axes[0].set_title(
    f"Walc по уровням goout\n"
    f"ANOVA: F={f_62:.3f}, p={p_62:.5f} | "
    f"KW: H={h_62:.3f}, p={pkw_62:.5f}",
    fontsize=11, fontweight="bold",
    color="#27ae60" if pkw_62 < 0.05 else "#c0392b")
axes[0].set_xlabel("goout (1=почти никогда, 5=очень часто)")
axes[0].set_ylabel("Walc — алкоголь в выходные")

# График средних
means_62 = df.groupby("goout")["Walc"].mean()
sems_62  = df.groupby("goout")["Walc"].sem()

axes[1].errorbar(means_62.index, means_62.values,
                 yerr=1.96*sems_62.values,
                 fmt="o-", color="#2c3e50",
                 markersize=10, linewidth=2.5,
                 capsize=8, capthick=2,
                 label="Среднее ± 95% ДИ")
for lvl, val in means_62.items():
    axes[1].annotate(
        f"{val:.2f}", (lvl, val),
        textcoords="offset points",
        xytext=(0, 12), ha="center",
        fontsize=10, fontweight="bold",
        color=palette_g[lvl-1])

# Подсветка значимых пар
if pkw_62 < 0.05:
    sig_pairs_62 = tk_62_raw[tk_62_raw["Значимо?"] == "✅ Да"]
    y_top = means_62.max() + 0.3
    for i, (_, row) in enumerate(sig_pairs_62.iterrows()):
        y = y_top + i * 0.25
        g1_v, g2_v = int(row["Группа 1"]), int(row["Группа 2"])
        axes[1].annotate(
            "", xy=(g2_v, y), xytext=(g1_v, y),
            arrowprops=dict(arrowstyle="<->",
                           color="#e74c3c", lw=1.5))
        axes[1].text(
            (g1_v + g2_v) / 2, y + 0.05,
            "✅", ha="center", fontsize=9, color="#e74c3c")

axes[1].set_title("Средние Walc по goout + значимые пары",
                  fontsize=12, fontweight="bold")
axes[1].set_xlabel("goout")
axes[1].set_ylabel("Средний Walc")
axes[1].set_xticks(sorted(df["goout"].unique()))
axes[1].legend()

plt.tight_layout()
plt.savefig("anova_Walc_goout.png", bbox_inches="tight")
plt.show()

# %%
# -------------------------------------------------------------
# 6.3 ANOVA: G3 по уровням Medu (образование матери, 5 групп)
# -------------------------------------------------------------

sh_63, an_63, f_63, p_63, h_63, pkw_63, \
    lbl_63, grp_63, sdf_63 = run_anova_full(
        df, "Medu", "G3",
        "Таблица 16 — ANOVA + Kruskal-Wallis: G3 по уровням Medu"
    )
display(sh_63)
display(an_63)
# Out:
# <style type="text/css">
# #T_72ba7 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_72ba7 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_72ba7 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_72ba7 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_72ba7_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_72ba7_row0_col4, #T_72ba7_row1_col4, #T_72ba7_row2_col4, #T_72ba7_row3_col4 {
#   background-color: #fde8d8;
# }
# #T_72ba7_row1_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_72ba7_row2_col1 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_72ba7_row3_col1 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_72ba7_row4_col1 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_72ba7_row4_col4 {
#   background-color: #d5f5e3;
# }
# </style>
# <table id="T_72ba7">
#   <caption>Тест Шапиро-Уилка — нормальность групп (Medu)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72ba7_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_72ba7_level0_col1" class="col_heading level0 col1" >Среднее</th>
#       <th id="T_72ba7_level0_col2" class="col_heading level0 col2" >W-статистика</th>
#       <th id="T_72ba7_level0_col3" class="col_heading level0 col3" >p-value</th>
#       <th id="T_72ba7_level0_col4" class="col_heading level0 col4" >Нормальность</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Группа</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72ba7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72ba7_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_72ba7_row0_col1" class="data row0 col1" >13.000</td>
#       <td id="T_72ba7_row0_col2" class="data row0 col2" >0.7500</td>
#       <td id="T_72ba7_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_72ba7_row0_col4" class="data row0 col4" >⚠️ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_72ba7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72ba7_row1_col0" class="data row1 col0" >59</td>
#       <td id="T_72ba7_row1_col1" class="data row1 col1" >8.678</td>
#       <td id="T_72ba7_row1_col2" class="data row1 col2" >0.8718</td>
#       <td id="T_72ba7_row1_col3" class="data row1 col3" >0.0001</td>
#       <td id="T_72ba7_row1_col4" class="data row1 col4" >⚠️ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_72ba7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72ba7_row2_col0" class="data row2 col0" >103</td>
#       <td id="T_72ba7_row2_col1" class="data row2 col1" >9.728</td>
#       <td id="T_72ba7_row2_col2" class="data row2 col2" >0.8992</td>
#       <td id="T_72ba7_row2_col3" class="data row2 col3" >0.0005</td>
#       <td id="T_72ba7_row2_col4" class="data row2 col4" >⚠️ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_72ba7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72ba7_row3_col0" class="data row3 col0" >99</td>
#       <td id="T_72ba7_row3_col1" class="data row3 col1" >10.303</td>
#       <td id="T_72ba7_row3_col2" class="data row3 col2" >0.9299</td>
#       <td id="T_72ba7_row3_col3" class="data row3 col3" >0.0055</td>
#       <td id="T_72ba7_row3_col4" class="data row3 col4" >⚠️ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_72ba7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_72ba7_row4_col0" class="data row4 col0" >131</td>
#       <td id="T_72ba7_row4_col1" class="data row4 col1" >11.763</td>
#       <td id="T_72ba7_row4_col2" class="data row4 col2" >0.9618</td>
#       <td id="T_72ba7_row4_col3" class="data row4 col3" >0.1062</td>
#       <td id="T_72ba7_row4_col4" class="data row4 col4" >✅ Да</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_db2bc caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_db2bc th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_db2bc td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_db2bc tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_db2bc_row8_col0, #T_db2bc_row11_col0, #T_db2bc_row14_col0 {
#   background-color: #d5f5e3;
# }
# </style>
# <table id="T_db2bc">
#   <caption>Таблица 16 — ANOVA + Kruskal-Wallis: G3 по уровням Medu</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db2bc_level0_col0" class="col_heading level0 col0" >Значение</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Параметр</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db2bc_level0_row0" class="row_heading level0 row0" >Количество групп</th>
#       <td id="T_db2bc_row0_col0" class="data row0 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row1" class="row_heading level0 row1" >Общее n</th>
#       <td id="T_db2bc_row1_col0" class="data row1 col0" >395</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row2" class="row_heading level0 row2" >─── Проверка условий ───</th>
#       <td id="T_db2bc_row2_col0" class="data row2 col0" >──────────────────</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row3" class="row_heading level0 row3" >Тест Левена (p-value)</th>
#       <td id="T_db2bc_row3_col0" class="data row3 col0" >0.897200</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row4" class="row_heading level0 row4" >Однородность дисперсий</th>
#       <td id="T_db2bc_row4_col0" class="data row4 col0" >✅ Однородны</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row5" class="row_heading level0 row5" >Нормальность (Шапиро)</th>
#       <td id="T_db2bc_row5_col0" class="data row5 col0" >⚠️ Нарушена</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row6" class="row_heading level0 row6" >─── ANOVA (параметрический) ───</th>
#       <td id="T_db2bc_row6_col0" class="data row6 col0" >──────────────────</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row7" class="row_heading level0 row7" >F-статистика</th>
#       <td id="T_db2bc_row7_col0" class="data row7 col0" >6.088400</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row8" class="row_heading level0 row8" >p-value ANOVA</th>
#       <td id="T_db2bc_row8_col0" class="data row8 col0" >0.000092</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row9" class="row_heading level0 row9" >─── Kruskal-Wallis (непараметрический) ───</th>
#       <td id="T_db2bc_row9_col0" class="data row9 col0" >──────────────────</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row10" class="row_heading level0 row10" >H-статистика</th>
#       <td id="T_db2bc_row10_col0" class="data row10 col0" >24.103900</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row11" class="row_heading level0 row11" >p-value Kruskal-Wallis</th>
#       <td id="T_db2bc_row11_col0" class="data row11 col0" >0.000076</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row12" class="row_heading level0 row12" >─── Вывод ───</th>
#       <td id="T_db2bc_row12_col0" class="data row12 col0" >──────────────────</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row13" class="row_heading level0 row13" >Рекомендуемый тест</th>
#       <td id="T_db2bc_row13_col0" class="data row13 col0" >Kruskal-Wallis (условия нарушены)</td>
#     </tr>
#     <tr>
#       <th id="T_db2bc_level0_row14" class="row_heading level0 row14" >Итоговый вывод</th>
#       <td id="T_db2bc_row14_col0" class="data row14 col0" >✅ Отвергаем H₀</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **H₀:** Средняя итоговая оценка G3 одинакова во всех группах
# по уровню образования матери (Medu 0–4).
# **H₁:** Хотя бы одна группа имеет значимо отличающееся среднее G3.
#
# **Обоснование:**
# Medu имеет 5 уровней → ANOVA. Pearson-корреляция:
# Medu × G3 r ≈ +0.217, p < 0.001 (heatmap, раздел 2.5).
# Гипотеза: более образованные матери создают лучшую учебную среду
# и сильнее мотивируют ребёнка — что ведёт к более высоким оценкам.
#
# **Связь с темой алкоголя:**
# Более образованные родители → лучшая успеваемость ребёнка.
# В сочетании с результатами 4.1 и 5.2 формируется полная картина:
# алкоголь снижает оценки, а образование матери их повышает —
# это два противонаправленных фактора влияния на G3.

# %%
# -------------------------------------------------------------
# 6.3 Пост-хок для G3 ~ Medu
# -------------------------------------------------------------

if pkw_63 < 0.05:
    tk_63, tk_63_raw = run_posthoc_bonferroni(df, "Medu", "G3")
    display(tk_63)
else:
    display(Markdown(
        "**Пост-хок не проводится** — результат незначим."))
# Out:
# <style type="text/css">
# #T_c32b7 caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_c32b7 th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_c32b7 td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_c32b7 tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_c32b7_row0_col6, #T_c32b7_row1_col6, #T_c32b7_row2_col6, #T_c32b7_row3_col6, #T_c32b7_row4_col6, #T_c32b7_row7_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_c32b7_row0_col7, #T_c32b7_row1_col7, #T_c32b7_row2_col7, #T_c32b7_row3_col7, #T_c32b7_row4_col7, #T_c32b7_row5_col7, #T_c32b7_row7_col7, #T_c32b7_row9_col7 {
#   background-color: #fde8d8;
# }
# #T_c32b7_row5_col6 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_c32b7_row6_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_c32b7_row6_col7, #T_c32b7_row8_col7 {
#   background-color: #d5f5e3;
# }
# #T_c32b7_row8_col6 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_c32b7_row9_col6 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c32b7">
#   <caption>Пост-хок анализ — попарные t-тесты + поправка Бонферрони</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c32b7_level0_col0" class="col_heading level0 col0" >Группа 1</th>
#       <th id="T_c32b7_level0_col1" class="col_heading level0 col1" >Группа 2</th>
#       <th id="T_c32b7_level0_col2" class="col_heading level0 col2" >Среднее (гр. 1)</th>
#       <th id="T_c32b7_level0_col3" class="col_heading level0 col3" >Среднее (гр. 2)</th>
#       <th id="T_c32b7_level0_col4" class="col_heading level0 col4" >Разница средних</th>
#       <th id="T_c32b7_level0_col5" class="col_heading level0 col5" >p-value (сырой)</th>
#       <th id="T_c32b7_level0_col6" class="col_heading level0 col6" >p-value (Бонферрони)</th>
#       <th id="T_c32b7_level0_col7" class="col_heading level0 col7" >Значимо?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c32b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c32b7_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c32b7_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_c32b7_row0_col2" class="data row0 col2" >13.000</td>
#       <td id="T_c32b7_row0_col3" class="data row0 col3" >8.678</td>
#       <td id="T_c32b7_row0_col4" class="data row0 col4" >4.322</td>
#       <td id="T_c32b7_row0_col5" class="data row0 col5" >0.15459</td>
#       <td id="T_c32b7_row0_col6" class="data row0 col6" >1.00000</td>
#       <td id="T_c32b7_row0_col7" class="data row0 col7" >❌ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_c32b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c32b7_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_c32b7_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_c32b7_row1_col2" class="data row1 col2" >13.000</td>
#       <td id="T_c32b7_row1_col3" class="data row1 col3" >9.728</td>
#       <td id="T_c32b7_row1_col4" class="data row1 col4" >3.272</td>
#       <td id="T_c32b7_row1_col5" class="data row1 col5" >0.23983</td>
#       <td id="T_c32b7_row1_col6" class="data row1 col6" >1.00000</td>
#       <td id="T_c32b7_row1_col7" class="data row1 col7" >❌ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_c32b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c32b7_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_c32b7_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_c32b7_row2_col2" class="data row2 col2" >13.000</td>
#       <td id="T_c32b7_row2_col3" class="data row2 col3" >10.303</td>
#       <td id="T_c32b7_row2_col4" class="data row2 col4" >2.697</td>
#       <td id="T_c32b7_row2_col5" class="data row2 col5" >0.30823</td>
#       <td id="T_c32b7_row2_col6" class="data row2 col6" >1.00000</td>
#       <td id="T_c32b7_row2_col7" class="data row2 col7" >❌ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_c32b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c32b7_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_c32b7_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_c32b7_row3_col2" class="data row3 col2" >13.000</td>
#       <td id="T_c32b7_row3_col3" class="data row3 col3" >11.763</td>
#       <td id="T_c32b7_row3_col4" class="data row3 col4" >1.237</td>
#       <td id="T_c32b7_row3_col5" class="data row3 col5" >0.60151</td>
#       <td id="T_c32b7_row3_col6" class="data row3 col6" >1.00000</td>
#       <td id="T_c32b7_row3_col7" class="data row3 col7" >❌ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_c32b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c32b7_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_c32b7_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_c32b7_row4_col2" class="data row4 col2" >8.678</td>
#       <td id="T_c32b7_row4_col3" class="data row4 col3" >9.728</td>
#       <td id="T_c32b7_row4_col4" class="data row4 col4" >-1.050</td>
#       <td id="T_c32b7_row4_col5" class="data row4 col5" >0.15220</td>
#       <td id="T_c32b7_row4_col6" class="data row4 col6" >1.00000</td>
#       <td id="T_c32b7_row4_col7" class="data row4 col7" >❌ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_c32b7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c32b7_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_c32b7_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_c32b7_row5_col2" class="data row5 col2" >8.678</td>
#       <td id="T_c32b7_row5_col3" class="data row5 col3" >10.303</td>
#       <td id="T_c32b7_row5_col4" class="data row5 col4" >-1.625</td>
#       <td id="T_c32b7_row5_col5" class="data row5 col5" >0.02861</td>
#       <td id="T_c32b7_row5_col6" class="data row5 col6" >0.28611</td>
#       <td id="T_c32b7_row5_col7" class="data row5 col7" >❌ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_c32b7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c32b7_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_c32b7_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_c32b7_row6_col2" class="data row6 col2" >8.678</td>
#       <td id="T_c32b7_row6_col3" class="data row6 col3" >11.763</td>
#       <td id="T_c32b7_row6_col4" class="data row6 col4" >-3.085</td>
#       <td id="T_c32b7_row6_col5" class="data row6 col5" >0.00001</td>
#       <td id="T_c32b7_row6_col6" class="data row6 col6" >0.00015</td>
#       <td id="T_c32b7_row6_col7" class="data row6 col7" >✅ Да</td>
#     </tr>
#     <tr>
#       <th id="T_c32b7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c32b7_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_c32b7_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_c32b7_row7_col2" class="data row7 col2" >9.728</td>
#       <td id="T_c32b7_row7_col3" class="data row7 col3" >10.303</td>
#       <td id="T_c32b7_row7_col4" class="data row7 col4" >-0.575</td>
#       <td id="T_c32b7_row7_col5" class="data row7 col5" >0.37871</td>
#       <td id="T_c32b7_row7_col6" class="data row7 col6" >1.00000</td>
#       <td id="T_c32b7_row7_col7" class="data row7 col7" >❌ Нет</td>
#     </tr>
#     <tr>
#       <th id="T_c32b7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c32b7_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_c32b7_row8_col1" class="data row8 col1" >4</td>
#       <td id="T_c32b7_row8_col2" class="data row8 col2" >9.728</td>
#       <td id="T_c32b7_row8_col3" class="data row8 col3" >11.763</td>
#       <td id="T_c32b7_row8_col4" class="data row8 col4" >-2.035</td>
#       <td id="T_c32b7_row8_col5" class="data row8 col5" >0.00067</td>
#       <td id="T_c32b7_row8_col6" class="data row8 col6" >0.00674</td>
#       <td id="T_c32b7_row8_col7" class="data row8 col7" >✅ Да</td>
#     </tr>
#     <tr>
#       <th id="T_c32b7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c32b7_row9_col0" class="data row9 col0" >3</td>
#       <td id="T_c32b7_row9_col1" class="data row9 col1" >4</td>
#       <td id="T_c32b7_row9_col2" class="data row

# %%
# -------------------------------------------------------------
# 6.3 Визуализация: G3 по уровням Medu
# -------------------------------------------------------------

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
palette_m = ["#e74c3c","#e67e22","#f39c12","#2ecc71","#27ae60"]

# Boxplot
sns.boxplot(data=df, x="Medu", y="G3",
            hue="Medu", palette=palette_m,
            width=0.5, linewidth=1.5,
            flierprops=dict(marker="o", alpha=0.4),
            legend=False, ax=axes[0])
axes[0].set_title(
    f"G3 по уровням Medu\n"
    f"ANOVA: F={f_63:.3f}, p={p_63:.5f} | "
    f"KW: H={h_63:.3f}, p={pkw_63:.5f}",
    fontsize=11, fontweight="bold",
    color="#27ae60" if pkw_63 < 0.05 else "#c0392b")
axes[0].set_xlabel("Medu (0=нет образования, 4=высшее)")
axes[0].set_ylabel("Итоговая оценка G3")

# Средние + пост-хок пары
means_63 = df.groupby("Medu")["G3"].mean()
sems_63  = df.groupby("Medu")["G3"].sem()

axes[1].errorbar(means_63.index, means_63.values,
                 yerr=1.96*sems_63.values,
                 fmt="o-", color="#2c3e50",
                 markersize=10, linewidth=2.5,
                 capsize=8, capthick=2,
                 label="Среднее ± 95% ДИ")
for lvl, val in means_63.items():
    axes[1].annotate(
        f"{val:.2f}", (lvl, val),
        textcoords="offset points",
        xytext=(0, 12), ha="center",
        fontsize=10, fontweight="bold",
        color=palette_m[lvl])

if pkw_63 < 0.05:
    sig_pairs_63 = tk_63_raw[tk_63_raw["Значимо?"] == "✅ Да"]
    y_top = means_63.max() + 0.5
    for i, (_, row) in enumerate(sig_pairs_63.iterrows()):
        y = y_top + i * 0.6
        g1_v, g2_v = int(row["Группа 1"]), int(row["Группа 2"])
        axes[1].annotate(
            "", xy=(g2_v, y), xytext=(g1_v, y),
            arrowprops=dict(arrowstyle="<->",
                           color="#27ae60", lw=1.5))
        axes[1].text(
            (g1_v + g2_v) / 2, y + 0.1,
            "✅", ha="center", fontsize=9, color="#27ae60")

axes[1].set_title("Средние G3 по Medu + значимые пары",
                  fontsize=12, fontweight="bold")
axes[1].set_xlabel("Medu")
axes[1].set_ylabel("Средняя G3")
axes[1].set_xticks(sorted(df["Medu"].unique()))
axes[1].legend()

plt.tight_layout()
plt.savefig("anova_G3_Medu.png", bbox_inches="tight")
plt.show()

# %%
# -------------------------------------------------------------
# 6.4 Сводная визуализация всех трёх ANOVA (обновлённая)
# -------------------------------------------------------------

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

anova_info = [
    (axes[0], "Walc",  "G3",
     f"G3 ~ Walc\nF={f_61:.2f} p={p_61:.3f} | KW p={pkw_61:.3f}",
     ["#2ecc71","#3498db","#f39c12","#e67e22","#e74c3c"], pkw_61),
    (axes[1], "goout", "Walc",
     f"Walc ~ goout\nF={f_62:.2f} p={p_62:.5f} | KW p={pkw_62:.5f}",
     ["#2ecc71","#3498db","#f39c12","#e67e22","#e74c3c"], pkw_62),
    (axes[2], "Medu",  "G3",
     f"G3 ~ Medu\nF={f_63:.2f} p={p_63:.5f} | KW p={pkw_63:.5f}",
     ["#e74c3c","#e67e22","#f39c12","#2ecc71","#27ae60"], pkw_63),
]

for ax, x_col, y_col, title, palette, p_kw in anova_info:
    unique_vals = sorted(df[x_col].unique())
    palette_map = {v: c for v, c in zip(unique_vals, palette)}
    df["_x_"] = df[x_col]

    sns.boxplot(data=df, x=x_col, y=y_col,
                hue="_x_", palette=palette_map,
                width=0.5, linewidth=1.5,
                flierprops=dict(marker="o", alpha=0.3),
                legend=False, ax=ax)

    means = df.groupby(x_col)[y_col].mean()
    ax.plot(range(len(means)), means.values,
            marker="D", color="#2c3e50",
            linewidth=2, markersize=7,
            linestyle="--", zorder=5)

    sig = "✅ Значимо" if p_kw < 0.05 else "❌ Незначимо"
    color_title = "#27ae60" if p_kw < 0.05 else "#c0392b"
    ax.set_title(title + f"\n{sig}", fontsize=10,
                 fontweight="bold", color=color_title)
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_col)

df.drop(columns=["_x_"], inplace=True, errors="ignore")

plt.suptitle("Анализ дисперсии — сводный обзор трёх ANOVA",
             fontsize=14, fontweight="bold", y=1.02)
plt.tight_layout()
plt.savefig("anova_summary.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# **Интерпретация сводного графика:**
# - **G3 ~ Walc** ❌: тренд снижения G3 виден визуально, но незначим —
#   высокая вариабельность внутри групп маскирует эффект.
# - **Walc ~ goout** ✅: сильнейший результат — социальная активность
#   является главным предиктором алкогольного поведения.
# - **G3 ~ Medu** ✅: образование матери значимо влияет на оценки ребёнка —
#   пост-хок укажет, между какими уровнями разница наибольшая.

# %% [markdown]
# ## VII. Выводы и рекомендации
#
# ### Основные результаты
#
# **Алкоголь и успеваемость:**
# Студенты с высоким потреблением алкоголя в выходные (Walc ≥ 4)
# пропускают занятия значимо чаще (+3 пропуска, MWU p = 0.0004).
# Студенты с провалами пьют значимо больше (t p = 0.016).
# При этом прямое влияние Walc на итоговую оценку G3 статистически
# не подтвердилось (ANOVA F p = 0.570, KW p = 0.244) — связь слабая
# (Spearman ρ = −0.104), маскируется высокой вариабельностью оценок.
#
# **Социальные факторы:**
# Частота выходов с друзьями (goout) — сильнейший предиктор алкоголя
# в датасете (ANOVA F = 22.45, KW H = 63.44, p ≈ 0).
# Студенты, часто выходящие с друзьями (goout = 4–5), пьют
# в 2+ раза больше, чем почти не выходящие (goout = 1–2).
# Юноши пьют значимо больше девушек (χ² p = 0.000032).
#
# **Образование матери:**
# Чем выше образование матери (Medu), тем выше итоговая оценка ребёнка
# (ANOVA p = 0.000092). Значимая разница — между Medu = 4 (высшее)
# и Medu = 1–2: дети образованных матерей учатся лучше.

# %% [markdown]
# ### Ограничения анализа
#
# - **Размер выборки:** 395 студентов — достаточно для базовых тестов,
#   но недостаточно для надёжного анализа малых подгрупп (например,
#   Walc=5, n=28; Medu=0, n=3).
# - **Самооценка:** переменные Dalc и Walc — субъективные ответы
#   студентов, возможно занижение реального потребления.
# - **Корреляция ≠ причинность:** все выявленные связи —
#   ассоциативные, не причинно-следственные.
# - **Один предмет:** датасет охватывает только математику —
#   выводы могут не распространяться на другие дисциплины.
#
# ### Направления дальнейшего анализа
#
# - Регрессионный анализ: одновременный учёт Walc, goout, Medu,
#   studytime для предсказания G3.
# - Сравнение с датасетом по португальскому языку
#   (student-por.csv) — проверка воспроизводимости.
# - Временной анализ: динамика G1 → G2 → G3 в разрезе групп Walc.

# %%
# =============================================================
# VII. Выводы и рекомендации
# =============================================================

from IPython.display import display, Markdown

summary_data = {
    "Тест": [
        "t-тест 4.1", "t-тест 4.2", "t-тест 4.3",
        "χ² 5.1", "χ² 5.2", "χ² 5.3",
        "ANOVA 6.1", "ANOVA 6.2", "ANOVA 6.3"
    ],
    "Переменные": [
        "G3: Walc≤2 vs Walc≥4",
        "absences: Walc≤2 vs Walc≥4",
        "Walc: failures>0 vs =0",
        "sex × Walc",
        "Dalc × failures",
        "goout × Walc",
        "G3 ~ Walc (5 гр.)",
        "Walc ~ goout (5 гр.)",
        "G3 ~ Medu (5 гр.)",
    ],
    "p-value": [
        "MWU = 0.033",
        "t = 0.007 / MWU = 0.0004",
        "t = 0.016 / MWU = 0.014",
        "0.000032",
        "0.000281",
        "< 0.000001",
        "KW = 0.244",
        "KW ≈ 0",
        "KW = 0.000076",
    ],
    "Вывод": [
        "✅ H₀ отвергается (MWU)",
        "✅ H₀ отвергается",
        "✅ H₀ отвергается",
        "✅ H₀ отвергается",
        "✅ H₀ отвергается",
        "✅ H₀ отвергается",
        "❌ H₀ не отвергается",
        "✅ H₀ отвергается",
        "✅ H₀ отвергается",
    ],
    "Практический вывод": [
        "Высокий Walc → ниже G3",
        "Высокий Walc → больше пропусков",
        "Провалы → больше алкоголя",
        "Юноши пьют значимо больше",
        "Высокий Dalc → больше провалов",
        "Частые выходы → больше алкоголя",
        "Walc слабо влияет на G3 напрямую",
        "goout — главный предиктор Walc",
        "Образование матери → выше G3",
    ]
}

summary_df = pd.DataFrame(summary_data)

styled_summary = summary_df.style \
    .apply(lambda col: [
        "background-color: #d5f5e3" if "✅" in v
        else "background-color: #fde8d8"
        for v in col], subset=["Вывод"]) \
    .set_caption(
        "Таблица 17 — Сводные результаты статистического анализа") \
    .set_table_styles(TABLE_HEADER_STYLE) \
    .hide(axis="index")

display(styled_summary)
# Out:
# <style type="text/css">
# #T_be89b caption {
#   font-size: 14px;
#   font-weight: bold;
#   color: #2c3e50;
#   padding-bottom: 10px;
#   text-align: left;
# }
# #T_be89b th {
#   background-color: #2c3e50;
#   color: white;
#   font-size: 12px;
#   padding: 8px 12px;
#   text-align: center;
# }
# #T_be89b td {
#   padding: 7px 12px;
#   font-size: 11px;
#   text-align: center;
# }
# #T_be89b tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_be89b_row0_col3, #T_be89b_row1_col3, #T_be89b_row2_col3, #T_be89b_row3_col3, #T_be89b_row4_col3, #T_be89b_row5_col3, #T_be89b_row7_col3, #T_be89b_row8_col3 {
#   background-color: #d5f5e3;
# }
# #T_be89b_row6_col3 {
#   background-color: #fde8d8;
# }
# </style>
# <table id="T_be89b">
#   <caption>Таблица 17 — Сводные результаты статистического анализа</caption>
#   <thead>
#     <tr>
#       <th id="T_be89b_level0_col0" class="col_heading level0 col0" >Тест</th>
#       <th id="T_be89b_level0_col1" class="col_heading level0 col1" >Переменные</th>
#       <th id="T_be89b_level0_col2" class="col_heading level0 col2" >p-value</th>
#       <th id="T_be89b_level0_col3" class="col_heading level0 col3" >Вывод</th>
#       <th id="T_be89b_level0_col4" class="col_heading level0 col4" >Практический вывод</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_be89b_row0_col0" class="data row0 col0" >t-тест 4.1</td>
#       <td id="T_be89b_row0_col1" class="data row0 col1" >G3: Walc≤2 vs Walc≥4</td>
#       <td id="T_be89b_row0_col2" class="data row0 col2" >MWU = 0.033</td>
#       <td id="T_be89b_row0_col3" class="data row0 col3" >✅ H₀ отвергается (MWU)</td>
#       <td id="T_be89b_row0_col4" class="data row0 col4" >Высокий Walc → ниже G3</td>
#     </tr>
#     <tr>
#       <td id="T_be89b_row1_col0" class="data row1 col0" >t-тест 4.2</td>
#       <td id="T_be89b_row1_col1" class="data row1 col1" >absences: Walc≤2 vs Walc≥4</td>
#       <td id="T_be89b_row1_col2" class="data row1 col2" >t = 0.007 / MWU = 0.0004</td>
#       <td id="T_be89b_row1_col3" class="data row1 col3" >✅ H₀ отвергается</td>
#       <td id="T_be89b_row1_col4" class="data row1 col4" >Высокий Walc → больше пропусков</td>
#     </tr>
#     <tr>
#       <td id="T_be89b_row2_col0" class="data row2 col0" >t-тест 4.3</td>
#       <td id="T_be89b_row2_col1" class="data row2 col1" >Walc: failures>0 vs =0</td>
#       <td id="T_be89b_row2_col2" class="data row2 col2" >t = 0.016 / MWU = 0.014</td>
#       <td id="T_be89b_row2_col3" class="data row2 col3" >✅ H₀ отвергается</td>
#       <td id="T_be89b_row2_col4" class="data row2 col4" >Провалы → больше алкоголя</td>
#     </tr>
#     <tr>
#       <td id="T_be89b_row3_col0" class="data row3 col0" >χ² 5.1</td>
#       <td id="T_be89b_row3_col1" class="data row3 col1" >sex × Walc</td>
#       <td id="T_be89b_row3_col2" class="data row3 col2" >0.000032</td>
#       <td id="T_be89b_row3_col3" class="data row3 col3" >✅ H₀ отвергается</td>
#       <td id="T_be89b_row3_col4" class="data row3 col4" >Юноши пьют значимо больше</td>
#     </tr>
#     <tr>
#       <td id="T_be89b_row4_col0" class="data row4 col0" >χ² 5.2</td>
#       <td id="T_be89b_row4_col1" class="data row4 col1" >Dalc × failures</td>
#       <td id="T_be89b_row4_col2" class="data row4 col2" >0.000281</td>
#       <td id="T_be89b_row4_col3" class="data row4 col3" >✅ H₀ отвергается</td>
#       <td id="T_be89b_row4_col4" class="data row4 col4" >Высокий Dalc → больше провалов</td>
#     </tr>
#     <tr>
#       <td id="T_be89b_row5_col0" class="data row5 col0" >χ² 5.3</td>
#       <td id="T_be89b_row5_col1" class="data row5 col1" >goout × Walc</td>
#       <td id="T_be89b_row5_col2" class="data row5 col2" >< 0.000001</td>
#       <td id="T_be89b_row5_col3" class="data row5 col3" >✅ H₀ отвергается</td>
#       <td id="T_be89b_row5_col4" class="data row5 col4" >Частые выходы → больше алкоголя</td>
#     </tr>
#     <tr>
#       <td id="T_be89b_row6_col0" class="data row6 col0" >ANOVA 6.1</td>
#       <td id="T_be89b_row6_col1" class="data row6 col1" >G3 ~ Walc (5 гр.)</td>
#       <td id="T_be89b_row6_col2" class="data row6 col2" >KW = 0.244</td>
#       <td id="T_be89b_row6_col3" class="data row6 col3" >❌ H₀ не отвергается</td>
#       <td id="T_be89b_row6_col4" class="data row6 col4" >Walc слабо влияет на G3 напрямую</td>
#     </tr>
#     <tr>
#       <td id="T_be89b_row7_col0" class="data row7 col0" >ANOVA 6.2</td>
#       <td id="T_be89b_row7_col1" class="data row7 col1" >Walc ~ goout (5 гр.)</td>
#       <td id="T_be89b_row7_col2" class="data row7 col2" >KW ≈ 0</td>
#       <td id="T_be89b_row7_col3" class="data row7 col3" >✅ H₀ отвергается</td>
#       <td id="T_be89b_row7_col4" class="data row7 col4" >goout — главный предиктор Walc</td>
#     </tr>
#     <tr>
#       <td id="T_be89b_row8_col0" class="data row8 col0" >ANOVA 6.3</td>
#       <td id="T_be89b_row8_col1" class="data row8 col1" >G3 ~ Medu (5 гр.)</td>
#       <td id="T_be89b_row8_col2" class="data row8 col2" >KW = 0.000076</td>
#       <td id="T_be89b_row8_col3" class="data row8 col3" >✅ H₀ отвергается</td>
#       <td id="T_be89b_row8_col4" class="data row8 col4" >Образование матери → выше G3</td>
#     </tr>
#   </tbody>
# </table>
